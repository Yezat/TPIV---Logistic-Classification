# %%
import os
import inspect
import sys
sys.path.insert(0, "../")


from experiment_information import *
from data import *
from helpers import *
from _version import __version__
import seaborn as sns
import matplotlib.pyplot as plt



import pandas as pd
import numpy as np
import logging
import pprint
import re
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
# mpl.rcParams['lines.linewidth'] = 1
# mpl.rcParams['legend.fontsize'] = 13

# mpl.rcParams['axes.titlesize'] = 15
# mpl.rcParams['axes.labelsize'] = 13
# mpl.rcParams['xtick.labelsize'] = 10
# mpl.rcParams['ytick.labelsize'] = 10

# %%
from _version import __version__
df_experiments = None
df_state_evolution = None
df_erm = None
logger = logging.getLogger()
# with DatabaseHandler(logger,"experiments/experiments.db") as dbHandler:
with DatabaseHandler(logger,"../experiments/experiments.db") as dbHandler:

    df_experiments = dbHandler.get_experiments()
    df_state_evolution = dbHandler.get_state_evolutions()
    df_state_evolution["calibrations"] = df_state_evolution["calibrations"].apply(lambda x: json.loads(x))
    df_erm = dbHandler.get_erms()
    df_erm["analytical_calibrations"] = df_erm["analytical_calibrations"].apply(lambda x: json.loads(x))
    df_erm["erm_calibrations"] = df_erm["erm_calibrations"].apply(lambda x: json.loads(x))
    # delete incomplete experiments (bad, deletes running experiments...)
    # dbHandler.delete_incomplete_experiments()

# def explode_calibrations(df):
#     a = df["calibrations"].apply(pd.Series)
#     # drop the original calibrations column
#     df = df.drop(columns=["calibrations"])
#     # concat the original dataframe with the new dataframe containing the exploded calibrations column
#     df = pd.concat([df,a],axis=1)
#     # explode both calibrations and ps columns
#     df = df.explode(["calibrations","ps"])
#     # rename the exploded columns
#     df = df.rename(columns={"calibrations":"calibration","ps":"p_calibration"})
#     return df
# df_state_evolution = explode_calibrations(df_state_evolution)
# def explode_erm_calibrations(df):
#     a = df["erm_calibrations"].apply(pd.Series)
#     # drop the original calibrations column
#     df = df.drop(columns=["erm_calibrations"])
#     b = df["analytical_calibrations"].apply(pd.Series)
#     # drop the original calibrations column
#     df = df.drop(columns=["analytical_calibrations"])
#     # drop the dp and ps columns from b
#     b = b.drop(columns=["dp","ps"])
#     # rename the columns of b
#     b = b.rename(columns={"calibrations":"analytical_calibration"})
#     # rename the columns of a
#     a = a.rename(columns={"calibrations":"erm_calibration"})
#     # concat the original dataframe with the new dataframe containing the exploded calibrations column
#     df = pd.concat([df,a],axis=1)
#     df = pd.concat([df,b],axis=1)
#     # explode both calibrations and ps columns
#     df = df.explode(["erm_calibration","analytical_calibration","ps"])
#     # rename the exploded columns
#     df = df.rename(columns={"ps":"p_calibration"})
#     return df
# df_erm = explode_erm_calibrations(df_erm)

def explode_measures(df, new_columns, columns):
    for column in columns:
        def transform(column):
            # replace NaN in the column string by 0
            column = column.replace("NaN","0")
            # replace null in the column string by 0
            column = column.replace("null","0")
            # replace Infinity in the column string by np.inf
            column = column.replace("Infinity","np.inf")
            return eval(column)
        df[column] = df[column].apply(transform)

    exploded = df.explode(columns).reset_index(drop=True)

    for new_column, column in zip(new_columns, columns):
        if len(exploded[column].tolist()) > 0:
            exploded[["attack_epsilon",new_column]] = pd.DataFrame(exploded[column].tolist(), index=exploded.index)
        else:
            exploded[new_column] = np.nan
            # set attack_epsilon
            exploded["attack_epsilon"] = np.nan

    exploded = exploded.drop(columns=columns)
    return exploded

def explode_erm_measures(df):
    columns = ["adversarial_generalization_errors","adversarial_generalization_errors_teacher","adversarial_generalization_errors_overlap","fair_adversarial_errors","test_losses","boundary_loss_test_es"]
    new_columns = ["adversarial_generalization_error","adversarial_generalization_error_teacher","adversarial_generalization_error_overlap","fair_adversarial_error","test_loss","boundary_loss_test"]
    return explode_measures(df, new_columns, columns)

def explode_state_evolution_measures(df):
    columns = ["adversarial_generalization_errors","adversarial_generalization_errors_teacher","fair_adversarial_errors","first_term_fair_errors","second_term_fair_errors","third_term_fair_errors","test_losses","data_model_adversarial_generalization_errors","gamma_robustness_es","boundary_loss_test_es"]
    new_columns = ["adversarial_generalization_error","adversarial_generalization_error_teacher","fair_adversarial_error","first_term_fair_error","second_term_fair_error","third_term_fair_error","test_loss","data_model_adversarial_generalization_error","gamma_robustness","boundary_loss_test"] #
    # columns = ["adversarial_generalization_errors","adversarial_generalization_errors_teacher","fair_adversarial_errors","second_term_fair_errors","test_losses","data_model_adversarial_generalization_errors"]
    # new_columns = ["adversarial_generalization_error","adversarial_generalization_error_teacher","fair_adversarial_error","second_term_fair_error","test_loss","data_model_adversarial_generalization_error"] #
    return explode_measures(df, new_columns, columns)
    

df_erm = explode_erm_measures(df_erm)

df_state_evolution = explode_state_evolution_measures(df_state_evolution)
    

print("Current code version, ", __version__)
# Out:
# Current code version,  101

# %%
def extract_first_eigenvalue(row, column):
    array = row[column]

    # load json string to array
    array = json.loads(array)
    return np.array([float(array[0])])
def extract_second_eigenvalue(row, column):
    array = row[column]

    # load json string to array
    array = json.loads(array)
    return np.array([float(array[-1])])
def extract_trace(row, column):
    array = row[column]

    # load json string to array
    array = json.loads(array)
    return np.array([float(sum(array))])

df2 = df_state_evolution.reset_index()


df2["sigmax_first_ev"] = df2.apply(lambda row: extract_first_eigenvalue(row, "sigmax_eigenvalues"), axis=1)
df2["sigmax_second_ev"] = df2.apply(lambda row: extract_second_eigenvalue(row, "sigmax_eigenvalues"), axis=1)
df2["sigmax_trace"] = df2.apply(lambda row: extract_trace(row, "sigmax_eigenvalues"), axis=1)

df2["sigmatheta_first_ev"] = df2.apply(lambda row: extract_first_eigenvalue(row, "sigmatheta_eigenvalues"), axis=1)
df2["sigmatheta_second_ev"] = df2.apply(lambda row: extract_second_eigenvalue(row, "sigmatheta_eigenvalues"), axis=1)
df2["sigmatheta_trace"] = df2.apply(lambda row: extract_trace(row, "sigmatheta_eigenvalues"), axis=1)

df2["xtheta_first_ev"] = df2.apply(lambda row: extract_first_eigenvalue(row, "xtheta_eigenvalues"), axis=1)
df2["xtheta_second_ev"] = df2.apply(lambda row: extract_second_eigenvalue(row, "xtheta_eigenvalues"), axis=1)
df2["xtheta_trace"] = df2.apply(lambda row: extract_trace(row, "xtheta_eigenvalues"), axis=1)

# columns = ["sigmax_first_ev","sigmax_second_ev","sigmax_trace","sigmatheta_first_ev","sigmatheta_second_ev","sigmatheta_trace","xtheta_first_ev","xtheta_second_ev","xtheta_trace"]

# for column in columns:
#     # apply mean and std to the new column
#     df_result = df2[column].apply(lambda x: pd.Series({"mean":x, "std":0}))
#     multiindex = pd.MultiIndex.from_product([[column], ['mean', 'std']], names=['', ''])
#     df_result.columns = multiindex
#     # Concatenate the original DataFrame with the computed values DataFrame
#     df2 = pd.concat([df2, df_result], axis=1)

# drop the original eigenvalues columns
df2 = df2.drop(columns=["sigmax_eigenvalues","sigmatheta_eigenvalues","xtheta_eigenvalues"])

df_state_evolution = df2

# df_state_evolution

# %%
# get the completed experiments with the current code version ordered by date
version_choice = __version__
version_choice = "100"
df_experiments = df_experiments[(df_experiments["completed"]==True) & (df_experiments["code_version"]==version_choice)]
df_experiments = df_experiments.sort_values(by="date",ascending=False)
df_experiments.head(3)
# Out:
#                            experiment_id    experiment_name   duration  \
# 55  97f18c50-5922-4b00-bbb4-6026be9970ae    OverlapScalings  10.631026
# 54  62213053-2758-45e7-8ee9-05cf0dd72e0f  PowerLawBetaSweep  66.651880
# 53  14de8cb0-38e1-412f-ba8d-8372934d8d52  PowerLawBetaSweep  42.126652
#
#    problem_types code_version                 date  \
# 55  ["Logistic"]          100  2024-01-29 13:36:29
# 54  ["Logistic"]          100  2024-01-29 11:11:31
# 53  ["Logistic"]          100  2024-01-29 11:01:17
#
#     state_evolution_repetitions  erm_repetitions  \
# 55                            1                0
# 54                            1                0
# 53                            1                0
#
#                                                alphas    epsilons  ...  \
# 55  [0.1585, 0.232, 0.3397, 0.4972, 0.7279, 1.0656...       [0.2]  ...
# 54                                        [1000000.0]  [0.0, 0.2]  ...
# 53                                        [1000000.0]  [0.0, 0.2]  ...
#
#       taus    ps    dp     d  experiment_type  completed  \
# 55   [0.5]  null  0.01  1000            Sweep          1
# 54  [0.05]  null  0.01   500            Sweep          1
# 53  [0.05]  null  0.01   500            Sweep          1
#
#                                      data_model_types  \
# 55                                 ["KFeaturesModel"]
# 54  ["KFeaturesModel", "KFeaturesModel", "KFeature...
# 53  ["KFeaturesModel", "KFeaturesModel", "KFeature...
#
#                                      data_model_names  \
# 55  ["KFeaturesModel_Vanilla_ProtectingIdentity_At...
# 54  ["KFeaturesModel_PowerLaw_Coefficient_1.01___P...
# 53  ["KFeaturesModel_PowerLaw_Coefficient_1.01___P...
#
#                               data_model_descriptions gamma_fair_error
# 55  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
# 54  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
# 53  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
#
# [3 rows x 22 columns]

# %%
df_state_evolution["estimation_error"] = 1 + df_state_evolution["q"] - 2 * df_state_evolution["m"]

# %%
experiment_loc = 0

# extract experiment by id "250fa46e-55cb-40d2-b503-11b38823235d"
# experiment_id = "d43ae27a-cf92-4261-a7d1-de5c9717f775"


# extract and print the top experiment_id
experiment_id = df_experiments.iloc[experiment_loc]["experiment_id"]
print(experiment_id)

# extract and print the experiment type
experiment_type = df_experiments.iloc[experiment_loc]["experiment_type"]
print(experiment_type)

# extract and print the data model type and data_model name used
data_model_types = df_experiments.iloc[experiment_loc]["data_model_types"]
# convert it to the enum
data_model_types = [DataModelType[data_model_type] for data_model_type in json.loads(data_model_types)]
data_model_names = [name for name in json.loads(df_experiments.iloc[experiment_loc]["data_model_names"])]
data_model_descriptions = df_experiments.iloc[experiment_loc]["data_model_descriptions"]
for data_model_type in data_model_types:
    print(data_model_type.name)
print(data_model_names)
print(data_model_descriptions)

# print the experiment name
experiment_name = df_experiments.iloc[experiment_loc]["experiment_name"]
print(experiment_name)

# print the experiment problem types
experiment_problem_types = df_experiments.iloc[experiment_loc]["problem_types"]
experiment_problem_types = json.loads(experiment_problem_types)
print(experiment_problem_types)
# Out:
# 97f18c50-5922-4b00-bbb4-6026be9970ae
# Sweep
# KFeaturesModel
# ['KFeaturesModel_Vanilla_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[1 1]_[1 1]_SD_1_1_SU_1_1___OverlapScalings']
# ["2 Features, Theta Identity, Sigma_upsilon Identity, Sigma_delta Identity"]
# OverlapScalings
# ['Logistic']

# %%
data_model_name_dict = {}
data_model_name_dict["VanillaGaussian"] = "Vanilla Gaussian"
data_model_name_dict["2_VanillaGaussian"] = "Vanilla Gaussian"
data_model_name_dict["VanillaGaussianThetaFirst"] = "Vanilla Gaussian - Teacher 10:1"
data_model_name_dict["VanillaGaussianTimes10"] = "Vanilla Gaussian x10"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[1 1]"] = "Strong Weak 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[1 1]"] = "Strong Weak 5:1"
data_model_name_dict["2_KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[1 1]"] = "Strong Weak 5:1"
data_model_name_dict["2_KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[1 1]"] = "Strong Weak 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[10  1]"] = "Strong Weak 5:1 - Teacher 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[10  1]"] = "Strong Weak 10:1 - Teacher 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[ 1 10]"] = "Strong Weak 5:1 - Teacher 1:10"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[ 1 10]"] = "Strong Weak 10:1 - Teacher 1:10"

# %%
state_evolution = df_state_evolution[df_state_evolution["experiment_id" ] == experiment_id]
gd = df_erm[df_erm["experiment_id" ] == experiment_id]
# make the column subspace_overlaps to string
state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: str(x))
gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: str(x))

# create a json colum
state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: json.loads(x))
gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: json.loads(x))
from pandas import json_normalize
# normalize the json column
normalized = json_normalize(state_evolution["subspace_overlaps"])
normalized_gd = json_normalize(gd["subspace_overlaps"])



def explode_array_column(row, col):
    return pd.Series(row[col])

# reset the index of the original dataframe
state_evolution = state_evolution.reset_index(drop=True)
gd = gd.reset_index(drop=True)

for col in normalized.columns:
    expanded_cols = normalized.apply(lambda x: explode_array_column(x,col), axis=1)
    col = col[:-1]
    expanded_cols.columns = [col+'_{}'.format(i) for i in range(expanded_cols.shape[1])]
    # reset the index of the expanded columns
    expanded_cols = expanded_cols.reset_index(drop=True)
    state_evolution = pd.concat([state_evolution, expanded_cols], axis=1)

for col in normalized_gd.columns:
    expanded_cols = normalized_gd.apply(lambda x: explode_array_column(x,col), axis=1)
    col = col[:-1]
    expanded_cols.columns = [col+'_{}'.format(i) for i in range(expanded_cols.shape[1])]
    # reset the index of the expanded columns
    expanded_cols = expanded_cols.reset_index(drop=True)

    gd = pd.concat([gd, expanded_cols], axis=1)
# Out:
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_2334/3541688095.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: str(x))
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_2334/3541688095.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: json.loads(x))

# %%
state_evolution["subspace_overlaps_ratio"] = state_evolution["subspace_overlaps_ratio"].apply(lambda x: str(x))
state_evolution["subspace_overlaps_ratio"] = state_evolution["subspace_overlaps_ratio"].apply(lambda x: json.loads(x))
normalized = json_normalize(state_evolution["subspace_overlaps_ratio"])
# rename the columns of the normalized dataframe
for column in normalized.columns:
    normalized = normalized.rename(columns={column:column+"_ratio"})
# merge the normalized dataframe with the original dataframe
state_evolution = pd.concat([state_evolution, normalized], axis=1)
# drop the original subspace_overlaps column
state_evolution = state_evolution.drop(columns=["subspace_overlaps_ratio"])

gd["subspace_overlaps_ratio"] = gd["subspace_overlaps_ratio"].apply(lambda x: str(x))
gd["subspace_overlaps_ratio"] = gd["subspace_overlaps_ratio"].apply(lambda x: json.loads(x))
normalized = json_normalize(gd["subspace_overlaps_ratio"])
# rename the columns of the normalized dataframe
for column in normalized.columns:
    normalized = normalized.rename(columns={column:column+"_ratio"})
# merge the normalized dataframe with the original dataframe
gd = pd.concat([gd, normalized], axis=1)
# drop the original subspace_overlaps column
gd = gd.drop(columns=["subspace_overlaps_ratio"])

# %%
# create a column for the difference between the adversarial_generalization_error and the generalization_error for both the state evolution and the erm
state_evolution["difference_adv_gen"] = state_evolution["adversarial_generalization_error"] - state_evolution["generalization_error"]
gd["difference_adv_gen"] = gd["adversarial_generalization_error"] - gd["generalization_error_erm"]


state_evolution["ratio_adv_gen"] = state_evolution["adversarial_generalization_error"] / state_evolution["generalization_error"]
gd["ratio_adv_gen"] = gd["adversarial_generalization_error"] / gd["generalization_error_erm"]

# %%
# create a column for the noise contribution
def noise_contribution(rho: float, tau: float) -> float:
    if tau == 0:
        tau = 1e-10
    return 0.5 - np.arctan( np.sqrt( rho / tau**2 ) ) / np.pi

state_evolution["noise_contribution"] = state_evolution.apply(lambda x: noise_contribution(x["rho"], x["tau"]), axis=1)
gd["noise_contribution"] = gd.apply(lambda x: noise_contribution(x["rho"], x["tau"]), axis=1)

# %%
# create a column for the noiseless generalization error without the noise contribution
state_evolution["noiseless_generalization_error"] = state_evolution["generalization_error"] - state_evolution["noise_contribution"]
gd["noiseless_generalization_error_erm"] = gd["generalization_error_erm"] - gd["noise_contribution"]

# create a column for the adversarial noiseless generalization error without the noise contribution
state_evolution["noiseless_adversarial_generalization_error"] = state_evolution["adversarial_generalization_error"] - state_evolution["noise_contribution"]
gd["noiseless_adversarial_generalization_error"] = gd["adversarial_generalization_error"] - gd["noise_contribution"]

# %%
# create a column for the A/sqrt(q*N) for both the state evolution and the erm
state_evolution["A_over_sqrt_qN"] = state_evolution["A"] / np.sqrt(state_evolution["q"] * state_evolution["N"])
gd["A_over_sqrt_qN"] = gd["A"] / np.sqrt(gd["q"] * gd["N"])

# %%
# create a column for m/sqrt( rho*q - m**2 ) vs A/sqrt(q*N) for both the state evolution and the erm
state_evolution["m_over_sqrt_rhoq_minus_m2"] = state_evolution["m"] / np.sqrt(state_evolution["rho"] * state_evolution["q"] - state_evolution["m"]**2)
gd["m_over_sqrt_rhoq_minus_m2"] = gd["m"] / np.sqrt(gd["rho"] * gd["q"] - gd["m"]**2)

# %%
# strip the data_model_name if there is a sequence ___text at the end
def strip_data_model_name(data_model_name):
    return re.sub(r"___.*","",data_model_name)
state_evolution["data_model_name"] = state_evolution["data_model_name"].apply(strip_data_model_name)
gd["data_model_name"] = gd["data_model_name"].apply(strip_data_model_name)

# %%
gd = gd.set_index(["alpha","epsilon","tau","lam","problem_type","attack_epsilon","data_model_name"]) #,"p_calibration"
state_evolution = state_evolution.set_index(["alpha","epsilon","tau","lam","problem_type","attack_epsilon","data_model_name"]) #,"p_calibration"

# drop id, code_version, experiment_id, date, initial_condition, test_against_epsilons, calibrations, abs_tol, min_iter,max_iter,blend_fpe,int_lims,subspace_overlaps
state_evolution = state_evolution.drop(columns=["id","code_version","experiment_id","date","initial_condition","test_against_epsilons","calibrations","abs_tol","min_iter","max_iter","blend_fpe","int_lims","subspace_overlaps","data_model_type","data_model_description"])
# drop id, code_version, experiment_id, test_against_epsilons, date, subspace_overlaps, analytical_calibrations, erm_calibrations, 
gd = gd.drop(columns=["id","code_version","experiment_id","test_against_epsilons","date","subspace_overlaps","analytical_calibrations","erm_calibrations","data_model_type","data_model_description"])

state_evolution.columns = [col+"_state_evolution" for col in state_evolution.columns]
gd.columns = [col+"_erm" for col in gd.columns]

state_evolution = state_evolution.groupby(level=[0,1,2,3,4,5,6]).agg(["mean","std"]) #,4
gd = gd.groupby(level=[0,1,2,3,4,5,6]).agg(["mean","std"]) #,4
df = state_evolution.join(gd, how="outer")
df.sort_index()
df
# Out:
#                                                                                                             index_state_evolution  \
#                                                                                                                              mean
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2613.0
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2612.0
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2615.0
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2614.0
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2620.0
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2639.0
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2630.0
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2640.0
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2638.0
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2623.0
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2624.0
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2618.0
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2622.0
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2617.0
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2621.0
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2616.0
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2619.0
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2626.0
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2633.0
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2628.0
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2634.0
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2629.0
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2637.0
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2631.0
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2632.0
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2625.0
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2636.0
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2627.0
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2635.0
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                2641.0
#
#                                                                                                                  \
#                                                                                                             std
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
#
#                                                                                                             duration_state_evolution  \
#                                                                                                                                 mean
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.295420
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.274048
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.329762
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.333354
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.397330
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.801021
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.668494
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 2.095196
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.723752
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.459372
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.454946
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.383278
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.404334
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.358239
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.397416
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.355683
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.394550
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.342442
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.372915
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.338507
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.373925
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.340820
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.377160
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.349937
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.382626
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.322226
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.375583
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.328638
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.374346
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                 1.996196
#
#                                                                                                                  \
#                                                                                                             std
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
#
#                                                                                                             generalization_error_state_evolution  \
#                                                                                                                                             mean
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.420654
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.404920
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.386582
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.365631
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.342270
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.317232
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.291852
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.264979
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.223769
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.199433
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.183532
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.172561
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.164900
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.159551
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.155830
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.153252
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.151473
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.150249
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.149408
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.148832
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.148437
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.148167
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.147982
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.147856
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.147770
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.147711
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.147671
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.147643
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.147624
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                             0.147611
#
#                                                                                                                  \
#                                                                                                             std
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
#
#                                                                                                             training_loss_state_evolution  \
#                                                                                                                                      mean
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.006442
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.006878
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.007558
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.008693
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.010781
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.015295
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.028835
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.124739
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.301517
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.366014
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.402089
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.424463
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.438922
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.448466
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.454843
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.459137
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.462041
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.464013
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.465354
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.466267
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.466890
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.467314
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.467604
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.467802
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.467937
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.468029
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.468092
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.468135
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.468165
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                      0.468185
#
#                                                                                                                  \
#                                                                                                             std
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
#
#                                                                                                             training_error_state_evolution  \
#                                                                                                                                       mean
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.000000
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.000000
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.000000
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.000000
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.000000
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.000000
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.000000
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.000276
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.044974
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.081942
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.104148
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.118373
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.127786
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.134114
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.138402
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.141318
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.143306
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.144663
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.145589
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.146221
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.148437
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.148167
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.147982
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.147856
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.147770
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.147711
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.147671
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.147643
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.147624
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                       0.147611
#
#                                                                                                                  \
#                                                                                                             std
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
#
#                                                                                                              ...  \
#                                                                                                              ...
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name                                     ...
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...  ...
#
#                                                                                                             noise_contribution_erm  \
#                                                                                                                               mean
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                    NaN
# ...
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                NaN
#
#                                                                                                                  \
#                                                                                                             std
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
#
#                                                                                                             m_over_sqrt_rhoq_minus_m2_erm  \
#                                                                                                                                      mean
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac...                           NaN
#
#
#                                                                                                             std
# alpha      epsilon tau lam   problem_type attack_epsilon data_model_name
# 0.1585     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.2320     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.3397     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.4972     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 0.7279     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.0656     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1.5599     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2.2836     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3.3430     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4.8939     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 7.1643     0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10.4879    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 15.3535    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 22.4763    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 32.9034    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 48.1680    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 70.5141    0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 103.2270   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 151.1160   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 221.2216   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 323.8507   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 474.0914   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 694.0317   0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1016.0067  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 1487.3521  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 2177.3640  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 3187.4859  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 4666.2233  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 6830.9760  0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
# 10000.0000 0.2     0.5 0.001 Logistic     0.2            KFeaturesModel_Vanilla_ProtectingIdentity_Attac... NaN
#
# [30 rows x 210 columns]

# %%
# store the dataframe as a pickle file
if not os.path.exists("Pickles"):
    os.makedirs("Pickles")
if not os.path.exists("Pickles/overlap_scalings.pkl"):
    df.to_pickle("Pickles/overlap_scalings.pkl")

# %%
# read the pickles
df = pd.read_pickle("Pickles/overlap_scalings.pkl")

# %% [markdown]
# # extracting the data

# %%
# get unique epsilons
epsilons = df.index.get_level_values(1).unique()
epsilons
# Out:
# Index([0.2], dtype='float64', name='epsilon')

# %%
# get unique attack_epsilons
attack_epsilons = df.index.get_level_values(5).unique()
attack_epsilons
# Out:
# Index([0.2], dtype='float64', name='attack_epsilon')

# %%
# create a dictionary of dataframes for each data_model_name

alphas = df.index.get_level_values("alpha").unique()

adversarial_error= df["adversarial_generalization_error_state_evolution"]["mean"].values
generalization_error = df["generalization_error_state_evolution"]["mean"].values
boundary_error = df["difference_adv_gen_state_evolution"]["mean"].values


alphas = np.array(alphas)
adversarial_error = np.array(adversarial_error)
generalization_error = np.array(generalization_error)

# %% [markdown]
# # Figure saving

# %%
IMG_DIRECTORY = "./Assets/highAlpha"
if not os.path.exists(IMG_DIRECTORY):
    os.makedirs(IMG_DIRECTORY)


def save_plot(fig, name, formats=["pdf","jpg"], date=False):
    current_date = datetime.datetime.now().strftime("%Y-%m-%d")
    for f in formats:        
        path = "{}".format(name) + "_{}".format(current_date) + "." + f
        if not date:
            path = "{}".format(name) + "." + f
        fig.savefig(            
            os.path.join(IMG_DIRECTORY, path),
            format=f,
        )


def set_size(width, fraction=1, subplots=(1, 1)):
    if width == "thesis":
        width_pt = 426.79135
    elif width == "beamer":
        width_pt = 307.28987
    else:
        width_pt = width

    fig_width_pt = width_pt * fraction
    inches_per_pt = 1 / 72.27

    golden_ratio = (5**0.5 - 1) / 2

    fig_width_in = fig_width_pt * inches_per_pt
    fig_height_in = fig_width_in * (golden_ratio) * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)


width = 1.75 * 458.63788

plt.style.use("../latex_ready.mplstyle")

tuple_size = set_size(width, fraction=0.50)
tuple_size = (4.25,2.7)

multiplier = 0.9
second_multiplier = 0.7

fig, axs = plt.subplots(
    nrows=1,
    ncols=1,
    sharex=True,
    figsize=( tuple_size[0], tuple_size[1]),
    gridspec_kw={"hspace": 0},
)

# print the figure size
print("Figure size: ", tuple_size)
# print the figure size
print("Figure size: ", fig.get_size_inches())

from matplotlib.pyplot import Line2D

# ICML adjustments
fig.subplots_adjust(left=0.15)
fig.subplots_adjust(bottom=0.15)
fig.subplots_adjust(top=0.9)
fig.subplots_adjust(right=0.85)




linestyles = ["solid", "dashed", "dashdot", "dotted"]



axs.plot(alphas, adversarial_error, linestyle=linestyles[0],color="C0")
axs.plot(alphas, generalization_error, linestyle=linestyles[0],color="C1")
axs.plot(alphas, boundary_error,linestyle=linestyles[0], color="C2")




axs.set_xscale("log")
axs.set_yscale("log")
axs.set_ylabel(r"E", labelpad=2.0)
axs.set_xlabel(r"$\alpha$", labelpad=2.0)
axs.grid(which="both", axis="both", alpha=0.5)
axs.tick_params(axis='both', which='major', direction='in')
axs.tick_params(axis='both', which='minor', direction='in')
axs.minorticks_off()
axs.legend()




error_legend = []

error_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{adv}}$",color="C0"))
error_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{gen}}$",color="C1"))
error_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{bound}}$",color="C2"))

epsilon_legend = []

for idx, epsilon in enumerate(epsilons):
    epsilon_legend.append(Line2D([0],[0],color="black", linestyle=linestyles[idx], label=r"$\varepsilon_t={}$".format(epsilons[idx]))) 

custom_legend = error_legend + epsilon_legend

# for idx in range(len(error_legend)):
#     custom_legend.append(error_legend[idx])
#     custom_legend.append(epsilon_legend[idx])

fig.legend(handles=custom_legend, loc="upper center", ncol=4, handlelength=1.5)

# 
plt.legend()

save = True
if save:
    save_plot(
        fig,
        "high_alpha",
    )

plt.show()

# plt.tight_layout()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Figure size:  (4.25, 2.7)
# Figure size:  [4.25 2.7 ]
