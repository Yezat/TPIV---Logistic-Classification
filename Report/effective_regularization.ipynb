# %%
import os
import inspect
import sys
sys.path.insert(0, "../")


from experiment_information import *
from data import *
from helpers import *
from _version import __version__
import seaborn as sns
import matplotlib.pyplot as plt



import pandas as pd
import numpy as np
import logging
import pprint
import re
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
# mpl.rcParams['lines.linewidth'] = 1
# mpl.rcParams['legend.fontsize'] = 13

# mpl.rcParams['axes.titlesize'] = 15
# mpl.rcParams['axes.labelsize'] = 13
# mpl.rcParams['xtick.labelsize'] = 10
# mpl.rcParams['ytick.labelsize'] = 10
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from _version import __version__
df_experiments = None
df_state_evolution = None
df_erm = None
logger = logging.getLogger()
# with DatabaseHandler(logger,"experiments/experiments.db") as dbHandler:
with DatabaseHandler(logger,"../experiments/experiments2.db") as dbHandler:

    df_experiments = dbHandler.get_experiments()
    df_state_evolution = dbHandler.get_state_evolutions()
    df_state_evolution["calibrations"] = df_state_evolution["calibrations"].apply(lambda x: json.loads(x))
    df_erm = dbHandler.get_erms()
    df_erm["analytical_calibrations"] = df_erm["analytical_calibrations"].apply(lambda x: json.loads(x))
    df_erm["erm_calibrations"] = df_erm["erm_calibrations"].apply(lambda x: json.loads(x))
    # delete incomplete experiments (bad, deletes running experiments...)
    # dbHandler.delete_incomplete_experiments()

# def explode_calibrations(df):
#     a = df["calibrations"].apply(pd.Series)
#     # drop the original calibrations column
#     df = df.drop(columns=["calibrations"])
#     # concat the original dataframe with the new dataframe containing the exploded calibrations column
#     df = pd.concat([df,a],axis=1)
#     # explode both calibrations and ps columns
#     df = df.explode(["calibrations","ps"])
#     # rename the exploded columns
#     df = df.rename(columns={"calibrations":"calibration","ps":"p_calibration"})
#     return df
# df_state_evolution = explode_calibrations(df_state_evolution)
# def explode_erm_calibrations(df):
#     a = df["erm_calibrations"].apply(pd.Series)
#     # drop the original calibrations column
#     df = df.drop(columns=["erm_calibrations"])
#     b = df["analytical_calibrations"].apply(pd.Series)
#     # drop the original calibrations column
#     df = df.drop(columns=["analytical_calibrations"])
#     # drop the dp and ps columns from b
#     b = b.drop(columns=["dp","ps"])
#     # rename the columns of b
#     b = b.rename(columns={"calibrations":"analytical_calibration"})
#     # rename the columns of a
#     a = a.rename(columns={"calibrations":"erm_calibration"})
#     # concat the original dataframe with the new dataframe containing the exploded calibrations column
#     df = pd.concat([df,a],axis=1)
#     df = pd.concat([df,b],axis=1)
#     # explode both calibrations and ps columns
#     df = df.explode(["erm_calibration","analytical_calibration","ps"])
#     # rename the exploded columns
#     df = df.rename(columns={"ps":"p_calibration"})
#     return df
# df_erm = explode_erm_calibrations(df_erm)

def explode_measures(df, new_columns, columns):
    for column in columns:
        def transform(column):
            # replace NaN in the column string by 0
            column = column.replace("NaN","0")
            # replace null in the column string by 0
            column = column.replace("null","0")
            # replace Infinity in the column string by np.inf
            column = column.replace("Infinity","np.inf")
            return eval(column)
        df[column] = df[column].apply(transform)

    exploded = df.explode(columns).reset_index(drop=True)

    for new_column, column in zip(new_columns, columns):
        if len(exploded[column].tolist()) > 0:
            exploded[["attack_epsilon",new_column]] = pd.DataFrame(exploded[column].tolist(), index=exploded.index)
        else:
            exploded[new_column] = np.nan
            # set attack_epsilon
            exploded["attack_epsilon"] = np.nan

    exploded = exploded.drop(columns=columns)
    return exploded

def explode_erm_measures(df):
    columns = ["adversarial_generalization_errors","adversarial_generalization_errors_teacher","adversarial_generalization_errors_overlap","fair_adversarial_errors","test_losses","boundary_loss_test_es"]
    new_columns = ["adversarial_generalization_error","adversarial_generalization_error_teacher","adversarial_generalization_error_overlap","fair_adversarial_error","test_loss","boundary_loss_test"]
    return explode_measures(df, new_columns, columns)

def explode_state_evolution_measures(df):
    columns = ["adversarial_generalization_errors","adversarial_generalization_errors_teacher","fair_adversarial_errors","first_term_fair_errors","second_term_fair_errors","third_term_fair_errors","test_losses","data_model_adversarial_generalization_errors","gamma_robustness_es","boundary_loss_test_es"]
    new_columns = ["adversarial_generalization_error","adversarial_generalization_error_teacher","fair_adversarial_error","first_term_fair_error","second_term_fair_error","third_term_fair_error","test_loss","data_model_adversarial_generalization_error","gamma_robustness","boundary_loss_test"] #
    # columns = ["adversarial_generalization_errors","adversarial_generalization_errors_teacher","fair_adversarial_errors","second_term_fair_errors","test_losses","data_model_adversarial_generalization_errors"]
    # new_columns = ["adversarial_generalization_error","adversarial_generalization_error_teacher","fair_adversarial_error","second_term_fair_error","test_loss","data_model_adversarial_generalization_error"] #
    return explode_measures(df, new_columns, columns)
    

df_erm = explode_erm_measures(df_erm)

df_state_evolution = explode_state_evolution_measures(df_state_evolution)
    

print("Current code version, ", __version__)
# Out:
# Current code version,  101

# %%
def extract_first_eigenvalue(row, column):
    array = row[column]

    # load json string to array
    array = json.loads(array)
    return np.array([float(array[0])])
def extract_second_eigenvalue(row, column):
    array = row[column]

    # load json string to array
    array = json.loads(array)
    return np.array([float(array[-1])])
def extract_trace(row, column):
    array = row[column]

    # load json string to array
    array = json.loads(array)
    return np.array([float(sum(array))])

df2 = df_state_evolution.reset_index()


df2["sigmax_first_ev"] = df2.apply(lambda row: extract_first_eigenvalue(row, "sigmax_eigenvalues"), axis=1)
df2["sigmax_second_ev"] = df2.apply(lambda row: extract_second_eigenvalue(row, "sigmax_eigenvalues"), axis=1)
df2["sigmax_trace"] = df2.apply(lambda row: extract_trace(row, "sigmax_eigenvalues"), axis=1)

df2["sigmatheta_first_ev"] = df2.apply(lambda row: extract_first_eigenvalue(row, "sigmatheta_eigenvalues"), axis=1)
df2["sigmatheta_second_ev"] = df2.apply(lambda row: extract_second_eigenvalue(row, "sigmatheta_eigenvalues"), axis=1)
df2["sigmatheta_trace"] = df2.apply(lambda row: extract_trace(row, "sigmatheta_eigenvalues"), axis=1)

df2["xtheta_first_ev"] = df2.apply(lambda row: extract_first_eigenvalue(row, "xtheta_eigenvalues"), axis=1)
df2["xtheta_second_ev"] = df2.apply(lambda row: extract_second_eigenvalue(row, "xtheta_eigenvalues"), axis=1)
df2["xtheta_trace"] = df2.apply(lambda row: extract_trace(row, "xtheta_eigenvalues"), axis=1)

# columns = ["sigmax_first_ev","sigmax_second_ev","sigmax_trace","sigmatheta_first_ev","sigmatheta_second_ev","sigmatheta_trace","xtheta_first_ev","xtheta_second_ev","xtheta_trace"]

# for column in columns:
#     # apply mean and std to the new column
#     df_result = df2[column].apply(lambda x: pd.Series({"mean":x, "std":0}))
#     multiindex = pd.MultiIndex.from_product([[column], ['mean', 'std']], names=['', ''])
#     df_result.columns = multiindex
#     # Concatenate the original DataFrame with the computed values DataFrame
#     df2 = pd.concat([df2, df_result], axis=1)

# drop the original eigenvalues columns
df2 = df2.drop(columns=["sigmax_eigenvalues","sigmatheta_eigenvalues","xtheta_eigenvalues"])

df_state_evolution = df2

# df_state_evolution

# %%
# get the completed experiments with the current code version ordered by date
version_choice = __version__
version_choice = "100"
df_experiments = df_experiments[(df_experiments["completed"]==True) & (df_experiments["code_version"]==version_choice)]
df_experiments = df_experiments.sort_values(by="date",ascending=False)
df_experiments.head(3)
# Out:
#                           experiment_id    experiment_name    duration  \
# 1  e1fa1866-af67-424c-934d-31515d08610c  PerturbedLogistic   53.569924
# 0  003d86e6-5ed8-434a-932a-e5f067467e11  PerturbedLogistic  183.939190
#
#                               problem_types code_version                 date  \
# 1  ["PerturbedBoundaryCoefficientLogistic"]          100  2024-01-25 11:26:48
# 0  ["PerturbedBoundaryCoefficientLogistic"]          100  2024-01-25 11:21:58
#
#    state_evolution_repetitions  erm_repetitions  \
# 1                            1                8
# 0                            1                8
#
#                                               alphas              epsilons  \
# 1  [0.1585, 0.2855, 0.5142, 0.9261, 1.6681, 3.004...  [0.0, 0.1, 0.2, 0.3]
# 0  [0.1585, 0.2855, 0.5142, 0.9261, 1.6681, 3.004...  [0.0, 0.1, 0.2, 0.3]
#
#    ...    taus    ps    dp     d  experiment_type  completed  \
# 1  ...  [0.05]  null  0.01  1000            Sweep          1
# 0  ...  [0.05]  null  0.01  1000            Sweep          1
#
#      data_model_types                                   data_model_names  \
# 1  ["KFeaturesModel"]  ["KFeaturesModel_TwoFeatures_ProtectingSecondS...
# 0  ["KFeaturesModel"]  ["KFeaturesModel_TwoFeatures_ProtectingSecondS...
#
#                              data_model_descriptions gamma_fair_error
# 1  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
# 0  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
#
# [2 rows x 22 columns]

# %%
df_state_evolution["estimation_error"] = 1 + df_state_evolution["q"] - 2 * df_state_evolution["m"]

# %%
experiment_loc = 0

# extract experiment by id "250fa46e-55cb-40d2-b503-11b38823235d"
# experiment_id = "d43ae27a-cf92-4261-a7d1-de5c9717f775"


# extract and print the top experiment_id
experiment_id = df_experiments.iloc[experiment_loc]["experiment_id"]
print(experiment_id)

# extract and print the experiment type
experiment_type = df_experiments.iloc[experiment_loc]["experiment_type"]
print(experiment_type)

# extract and print the data model type and data_model name used
data_model_types = df_experiments.iloc[experiment_loc]["data_model_types"]
# convert it to the enum
data_model_types = [DataModelType[data_model_type] for data_model_type in json.loads(data_model_types)]
data_model_names = [name for name in json.loads(df_experiments.iloc[experiment_loc]["data_model_names"])]
data_model_descriptions = df_experiments.iloc[experiment_loc]["data_model_descriptions"]
for data_model_type in data_model_types:
    print(data_model_type.name)
print(data_model_names)
print(data_model_descriptions)

# print the experiment name
experiment_name = df_experiments.iloc[experiment_loc]["experiment_name"]
print(experiment_name)

# print the experiment problem types
experiment_problem_types = df_experiments.iloc[experiment_loc]["problem_types"]
experiment_problem_types = json.loads(experiment_problem_types)
print(experiment_problem_types)
# Out:
# e1fa1866-af67-424c-934d-31515d08610c
# Sweep
# KFeaturesModel
# ['KFeaturesModel_TwoFeatures_ProtectingSecondStronger_AttackingIdentity_[0.5 0.5]_[1 1]_[1 1]_SD_1_1_SU_1_1___PerturbedLogistic']
# ["2 Features, Theta Identity, Sigma_upsilon Identity, Sigma_delta Identity"]
# PerturbedLogistic
# ['PerturbedBoundaryCoefficientLogistic']

# %%
data_model_name_dict = {}
data_model_name_dict["VanillaGaussian"] = "Vanilla Gaussian"
data_model_name_dict["2_VanillaGaussian"] = "Vanilla Gaussian"
data_model_name_dict["VanillaGaussianThetaFirst"] = "Vanilla Gaussian - Teacher 10:1"
data_model_name_dict["VanillaGaussianTimes10"] = "Vanilla Gaussian x10"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[1 1]"] = "Strong Weak 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[1 1]"] = "Strong Weak 5:1"
data_model_name_dict["2_KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[1 1]"] = "Strong Weak 5:1"
data_model_name_dict["2_KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[1 1]"] = "Strong Weak 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[10  1]"] = "Strong Weak 5:1 - Teacher 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[10  1]"] = "Strong Weak 10:1 - Teacher 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[ 1 10]"] = "Strong Weak 5:1 - Teacher 1:10"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[ 1 10]"] = "Strong Weak 10:1 - Teacher 1:10"

# %%
state_evolution = df_state_evolution[df_state_evolution["experiment_id" ] == experiment_id]
gd = df_erm[df_erm["experiment_id" ] == experiment_id]
# make the column subspace_overlaps to string
state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: str(x))
gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: str(x))

# create a json colum
state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: json.loads(x))
gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: json.loads(x))
from pandas import json_normalize
# normalize the json column
normalized = json_normalize(state_evolution["subspace_overlaps"])
normalized_gd = json_normalize(gd["subspace_overlaps"])



def explode_array_column(row, col):
    return pd.Series(row[col])

# reset the index of the original dataframe
state_evolution = state_evolution.reset_index(drop=True)
gd = gd.reset_index(drop=True)

for col in normalized.columns:
    expanded_cols = normalized.apply(lambda x: explode_array_column(x,col), axis=1)
    col = col[:-1]
    expanded_cols.columns = [col+'_{}'.format(i) for i in range(expanded_cols.shape[1])]
    # reset the index of the expanded columns
    expanded_cols = expanded_cols.reset_index(drop=True)
    state_evolution = pd.concat([state_evolution, expanded_cols], axis=1)

for col in normalized_gd.columns:
    expanded_cols = normalized_gd.apply(lambda x: explode_array_column(x,col), axis=1)
    col = col[:-1]
    expanded_cols.columns = [col+'_{}'.format(i) for i in range(expanded_cols.shape[1])]
    # reset the index of the expanded columns
    expanded_cols = expanded_cols.reset_index(drop=True)

    gd = pd.concat([gd, expanded_cols], axis=1)
# Out:
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_15253/3541688095.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: str(x))
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_15253/3541688095.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: str(x))
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_15253/3541688095.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: json.loads(x))
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_15253/3541688095.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: json.loads(x))

# %%
state_evolution["subspace_overlaps_ratio"] = state_evolution["subspace_overlaps_ratio"].apply(lambda x: str(x))
state_evolution["subspace_overlaps_ratio"] = state_evolution["subspace_overlaps_ratio"].apply(lambda x: json.loads(x))
normalized = json_normalize(state_evolution["subspace_overlaps_ratio"])
# rename the columns of the normalized dataframe
for column in normalized.columns:
    normalized = normalized.rename(columns={column:column+"_ratio"})
# merge the normalized dataframe with the original dataframe
state_evolution = pd.concat([state_evolution, normalized], axis=1)
# drop the original subspace_overlaps column
state_evolution = state_evolution.drop(columns=["subspace_overlaps_ratio"])

gd["subspace_overlaps_ratio"] = gd["subspace_overlaps_ratio"].apply(lambda x: str(x))
gd["subspace_overlaps_ratio"] = gd["subspace_overlaps_ratio"].apply(lambda x: json.loads(x))
normalized = json_normalize(gd["subspace_overlaps_ratio"])
# rename the columns of the normalized dataframe
for column in normalized.columns:
    normalized = normalized.rename(columns={column:column+"_ratio"})
# merge the normalized dataframe with the original dataframe
gd = pd.concat([gd, normalized], axis=1)
# drop the original subspace_overlaps column
gd = gd.drop(columns=["subspace_overlaps_ratio"])

# %%
# create a column for the difference between the adversarial_generalization_error and the generalization_error for both the state evolution and the erm
state_evolution["difference_adv_gen"] = state_evolution["adversarial_generalization_error"] - state_evolution["generalization_error"]
gd["difference_adv_gen"] = gd["adversarial_generalization_error"] - gd["generalization_error_erm"]


state_evolution["ratio_adv_gen"] = state_evolution["adversarial_generalization_error"] / state_evolution["generalization_error"]
gd["ratio_adv_gen"] = gd["adversarial_generalization_error"] / gd["generalization_error_erm"]

# %%
# create a column for the noise contribution
def noise_contribution(rho: float, tau: float) -> float:
    if tau == 0:
        tau = 1e-10
    return 0.5 - np.arctan( np.sqrt( rho / tau**2 ) ) / np.pi

state_evolution["noise_contribution"] = state_evolution.apply(lambda x: noise_contribution(x["rho"], x["tau"]), axis=1)
gd["noise_contribution"] = gd.apply(lambda x: noise_contribution(x["rho"], x["tau"]), axis=1)

# %%
# create a column for the noiseless generalization error without the noise contribution
state_evolution["noiseless_generalization_error"] = state_evolution["generalization_error"] - state_evolution["noise_contribution"]
gd["noiseless_generalization_error_erm"] = gd["generalization_error_erm"] - gd["noise_contribution"]

# create a column for the adversarial noiseless generalization error without the noise contribution
state_evolution["noiseless_adversarial_generalization_error"] = state_evolution["adversarial_generalization_error"] - state_evolution["noise_contribution"]
gd["noiseless_adversarial_generalization_error"] = gd["adversarial_generalization_error"] - gd["noise_contribution"]

# %%
# create a column for the A/sqrt(q*N) for both the state evolution and the erm
state_evolution["A_over_sqrt_qN"] = state_evolution["A"] / np.sqrt(state_evolution["q"] * state_evolution["N"])
gd["A_over_sqrt_qN"] = gd["A"] / np.sqrt(gd["q"] * gd["N"])

# %%
# create a column for m/sqrt( rho*q - m**2 ) vs A/sqrt(q*N) for both the state evolution and the erm
state_evolution["m_over_sqrt_rhoq_minus_m2"] = state_evolution["m"] / np.sqrt(state_evolution["rho"] * state_evolution["q"] - state_evolution["m"]**2)
gd["m_over_sqrt_rhoq_minus_m2"] = gd["m"] / np.sqrt(gd["rho"] * gd["q"] - gd["m"]**2)

# %%
# strip the data_model_name if there is a sequence ___text at the end
def strip_data_model_name(data_model_name):
    return re.sub(r"___.*","",data_model_name)
state_evolution["data_model_name"] = state_evolution["data_model_name"].apply(strip_data_model_name)
gd["data_model_name"] = gd["data_model_name"].apply(strip_data_model_name)

# %%
gd = gd.set_index(["alpha","epsilon","tau","lam","problem_type","attack_epsilon","data_model_name"]) #,"p_calibration"
state_evolution = state_evolution.set_index(["alpha","epsilon","tau","lam","problem_type","attack_epsilon","data_model_name"]) #,"p_calibration"

# drop id, code_version, experiment_id, date, initial_condition, test_against_epsilons, calibrations, abs_tol, min_iter,max_iter,blend_fpe,int_lims,subspace_overlaps
state_evolution = state_evolution.drop(columns=["id","code_version","experiment_id","date","initial_condition","test_against_epsilons","calibrations","abs_tol","min_iter","max_iter","blend_fpe","int_lims","subspace_overlaps","data_model_type","data_model_description"])
# drop id, code_version, experiment_id, test_against_epsilons, date, subspace_overlaps, analytical_calibrations, erm_calibrations, 
gd = gd.drop(columns=["id","code_version","experiment_id","test_against_epsilons","date","subspace_overlaps","analytical_calibrations","erm_calibrations","data_model_type","data_model_description"])

state_evolution.columns = [col+"_state_evolution" for col in state_evolution.columns]
gd.columns = [col+"_erm" for col in gd.columns]

state_evolution = state_evolution.groupby(level=[0,1,2,3,4,5,6]).agg(["mean","std"]) #,4
gd = gd.groupby(level=[0,1,2,3,4,5,6]).agg(["mean","std"]) #,4
df = state_evolution.join(gd, how="outer")
df.sort_index()
df
# Out:
#                                                                                                                                   index_state_evolution  \
#                                                                                                                                                    mean
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  43.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  41.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  44.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  42.0
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  40.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  46.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  47.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  49.0
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  50.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  45.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  52.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  48.0
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  54.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  51.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  53.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  56.0
# 1.6681  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  57.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  55.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  58.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  60.0
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  61.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  59.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  63.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  64.0
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  62.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  65.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  67.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  68.0
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  66.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  70.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  71.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  69.0
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  72.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  73.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  75.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  74.0
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  76.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  77.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  79.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                  78.0
#
#                                                                                                                                        \
#                                                                                                                                   std
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 1.6681  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#
#                                                                                                                                   duration_state_evolution  \
#                                                                                                                                                       mean
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.662979
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.651371
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.670651
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.651996
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.256620
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.549395
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.728742
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.766196
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.759361
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.207518
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.302035
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.234787
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.873463
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.325219
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.299724
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.469440
# 1.6681  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.963001
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.362895
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 2.196261
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 2.292984
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 2.020748
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.693311
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 2.454479
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.984779
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.513696
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.253789
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 3.969047
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 2.721408
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.070268
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 4.674171
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 3.532607
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.892074
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 2.414987
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 4.415691
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 3.411560
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.931443
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 6.500257
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 4.625666
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 3.141319
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.882751
#
#                                                                                                                                        \
#                                                                                                                                   std
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 1.6681  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#
#                                                                                                                                   generalization_error_state_evolution  \
#                                                                                                                                                                   mean
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.399724
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.399739
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.399753
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.399769
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.366147
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.366194
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.366244
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.366297
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.322231
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.322372
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.322523
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.322687
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.266347
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.266694
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.267079
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.267507
# 1.6681  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.200272
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.200942
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.201713
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.202557
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.134090
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.134981
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.135770
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.133613
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.082281
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.082689
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.081994
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.087962
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.050037
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.050133
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.055798
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.063979
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.032818
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.034858
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.041374
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.048181
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.024361
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.026977
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.032150
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.037236
#
#                                                                                                                                        \
#                                                                                                                                   std
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 1.6681  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#
#                                                                                                                                   training_loss_state_evolution  \
#                                                                                                                                                            mean
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.005471
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.005869
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.006315
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.006816
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.005666
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.006247
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.006927
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.007730
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.006056
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.006960
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.008097
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.009556
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.006815
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.008388
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.010622
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.013964
# 1.6681  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.008204
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.011415
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.017193
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.029481
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.010488
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.018487
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.043085
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.156365
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.013745
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.038683
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.151260
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.289168
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.017804
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.083285
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.213230
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.337462
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.022345
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.113594
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.240491
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.361041
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.026659
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.128740
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.254337
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.373430
#
#                                                                                                                                        \
#                                                                                                                                   std
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# ...
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#
#                                                                                                                                   m_over_sqrt_rhoq_minus_m2_erm  \
#                                                                                                                                                            mean
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.329394
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.313747
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.322549
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.337890
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.453259
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.445325
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.440678
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.463461
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.616867
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.618938
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.628409
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.628170
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.905817
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.900121
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.911520
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.902390
# 1.6681  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      1.388358
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      1.380120
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      1.397702
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      1.377667
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      2.273031
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      2.257161
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      2.262089
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      2.248970
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.823833
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.824046
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.642929
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.031578
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      6.577719
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      6.346358
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      4.916010
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.955903
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                     11.132489
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      8.854255
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      6.635876
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      5.366710
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                     17.081818
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                     12.221154
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      8.962029
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      7.169359
#
#
#                                                                                                                                         std
# alpha   epsilon tau  lam   problem_type                         attack_epsilon data_model_name
# 0.1585  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.025617
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.020886
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.011021
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.013629
# 0.2855  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.015467
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.019840
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.027327
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.027907
# 0.5142  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.035593
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.033343
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.027942
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.026628
# 0.9261  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.039645
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.038255
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.032863
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.011448
# 1.6681  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.033486
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.061316
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.034068
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.042179
# 3.0045  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.111731
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.084645
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.064631
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.078010
# 5.4117  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.177693
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.134175
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.089499
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.054850
# 9.7474  0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.183084
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.064914
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.096925
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.103110
# 17.5568 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.418683
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.274479
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.089249
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.079026
# 31.6228 0.0     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.507179
#         0.1     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.215658
#         0.2     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.287547
#         0.3     0.05 0.001 PerturbedBoundaryCoefficientLogistic 0.2            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.148335
#
# [40 rows x 246 columns]

# %%
# store the dataframe as a pickle file
if not os.path.exists("Pickles"):
    os.makedirs("Pickles")
if not os.path.exists("Pickles/effective_regularisation.pkl"):
    df.to_pickle("Pickles/effective_regularisation.pkl")

# %%
# load the data
df = pd.read_pickle("Pickles/effective_regularisation.pkl")

# %% [markdown]
# # extracting the data

# %%
# get unique epsilons
epsilons = df.index.get_level_values(1).unique()
epsilons
# Out:
# Index([0.0, 0.1, 0.2, 0.3], dtype='float64', name='epsilon')

# %%
# get unique attack_epsilons
attack_epsilons = df.index.get_level_values(5).unique()
attack_epsilons
# Out:
# Index([0.2], dtype='float64', name='attack_epsilon')

# %%
# create a dictionary of dataframes for each data_model_name
epsilon_dict = {}
for epsilon in epsilons:

    eps_df = df.xs(epsilon, level="epsilon")
    

    alphas = eps_df.index.get_level_values("alpha").unique()
    adversarial_error_0 = eps_df["adversarial_generalization_error_state_evolution"]["mean"].values
    generalization_error_0 = eps_df["generalization_error_state_evolution"]["mean"].values
    boundary_error_0 = eps_df["difference_adv_gen_state_evolution"]["mean"].values
    class_preserving = eps_df["fair_adversarial_error_state_evolution"]["mean"].values

    adversarial_error_erm = eps_df["adversarial_generalization_error_erm"]["mean"].values
    generalization_error_erm = eps_df["generalization_error_erm_erm"]["mean"].values
    boundary_error_erm = eps_df["difference_adv_gen_erm"]["mean"].values
    class_preserving_erm = eps_df["fair_adversarial_error_erm"]["mean"].values

    adversarial_error_erm_std = eps_df["adversarial_generalization_error_erm"]["std"].values
    generalization_error_erm_std = eps_df["generalization_error_erm_erm"]["std"].values
    boundary_error_erm_std = eps_df["difference_adv_gen_erm"]["std"].values
    class_preserving_erm_std = eps_df["fair_adversarial_error_erm"]["std"].values


    alphas = np.array(alphas)
    adversarial_error_0 = np.array(adversarial_error_0)
    generalization_error_0 = np.array(generalization_error_0)
    boundary_error_0 = np.array(boundary_error_0)
    class_preserving = np.array(class_preserving)


    adversarial_error_erm = np.array(adversarial_error_erm)
    generalization_error_erm = np.array(generalization_error_erm)
    boundary_error_erm = np.array(boundary_error_erm)
    class_preserving_erm = np.array(class_preserving_erm)

    adversarial_error_erm_std = np.array(adversarial_error_erm_std)
    generalization_error_erm_std = np.array(generalization_error_erm_std)
    boundary_error_erm_std = np.array(boundary_error_erm_std)
    class_preserving_erm_std = np.array(class_preserving_erm_std)


    eps_0_dict = {}
    eps_0_dict["alphas"] = alphas
    eps_0_dict["adversarial_error"] = adversarial_error_0
    eps_0_dict["generalization_error"] = generalization_error_0
    eps_0_dict["boundary_error"] = boundary_error_0
    eps_0_dict["class_preserving"] = class_preserving

    eps_0_dict["adversarial_error_erm"] = adversarial_error_erm
    eps_0_dict["generalization_error_erm"] = generalization_error_erm
    eps_0_dict["boundary_error_erm"] = boundary_error_erm
    eps_0_dict["class_preserving_erm"] = class_preserving_erm

    eps_0_dict["adversarial_error_erm_std"] = adversarial_error_erm_std
    eps_0_dict["generalization_error_erm_std"] = generalization_error_erm_std
    eps_0_dict["boundary_error_erm_std"] = boundary_error_erm_std
    eps_0_dict["class_preserving_erm_std"] = class_preserving_erm_std



    epsilon_dict[epsilon] = eps_0_dict

# %% [markdown]
# # Figure saving

# %%
IMG_DIRECTORY = "./Assets/effective_regularisation"
if not os.path.exists(IMG_DIRECTORY):
    os.makedirs(IMG_DIRECTORY)


def save_plot(fig, name, formats=["pdf","jpg"], date=False):
    current_date = datetime.datetime.now().strftime("%Y-%m-%d")
    for f in formats:        
        path = "{}".format(name) + "_{}".format(current_date) + "." + f
        if not date:
            path = "{}".format(name) + "." + f
        fig.savefig(            
            os.path.join(IMG_DIRECTORY, path),
            format=f,
        )


def set_size(width, fraction=1, subplots=(1, 1)):
    if width == "thesis":
        width_pt = 426.79135
    elif width == "beamer":
        width_pt = 307.28987
    else:
        width_pt = width

    fig_width_pt = width_pt * fraction
    inches_per_pt = 1 / 72.27

    golden_ratio = (5**0.5 - 1) / 2

    fig_width_in = fig_width_pt * inches_per_pt
    fig_height_in = fig_width_in * (golden_ratio) * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)


width = 1.75 * 458.63788

multiplier = 1.25
width = multiplier * 234.8775

plt.style.use("../latex_ready.mplstyle")

tuple_size = set_size(width, fraction=0.50)
tuple_size = ( 2.5 , 2.4 )

fig, axs = plt.subplots(
    nrows=2,
    ncols=1,
    sharex=True,
    figsize=( tuple_size[0], tuple_size[1]),
    gridspec_kw={"hspace": 0},
)

# print the figure size
print("Figure size: ", tuple_size)
# print the figure size
print("Figure size: ", fig.get_size_inches())

from matplotlib.pyplot import Line2D

# ICML adjustments
fig.subplots_adjust(left=0.2)
fig.subplots_adjust(bottom=0.12)
fig.subplots_adjust(top=0.99)
fig.subplots_adjust(right=0.99)




linestyles = ["solid", "dashed", "dashdot", "dotted"]

for idx, (epsilon, eps_dict) in enumerate(epsilon_dict.items()):


    alphas = eps_dict["alphas"]
    adversarial_error = eps_dict["adversarial_error"]
    generalization_error = eps_dict["generalization_error"]
    boundary_error = eps_dict["boundary_error"]
    class_preserving = eps_dict["class_preserving"]

    adversarial_error_erm = eps_dict["adversarial_error_erm"]
    generalization_error_erm = eps_dict["generalization_error_erm"]
    boundary_error_erm = eps_dict["boundary_error_erm"]
    class_preserving_erm = eps_dict["class_preserving_erm"]

    adversarial_error_erm_std = eps_dict["adversarial_error_erm_std"]
    generalization_error_erm_std = eps_dict["generalization_error_erm_std"]
    boundary_error_erm_std = eps_dict["boundary_error_erm_std"]
    class_preserving_erm_std = eps_dict["class_preserving_erm_std"]


    axs[0].plot(alphas, adversarial_error,  color="C0", linestyle=linestyles[idx])
    axs[0].plot(alphas, generalization_error, color="C1", linestyle=linestyles[idx])
    axs[0].plot(alphas, boundary_error,  color="C2", linestyle=linestyles[idx])
    # axs[0].plot(alphas, class_preserving,  color="C3", linestyle=linestyles[idx])



    axs[1].plot(
        alphas,
        adversarial_error_erm,        
        linestyle=linestyles[idx],
        color="C0"
    )
    axs[1].plot(
        alphas,
        generalization_error_erm, 
        linestyle=linestyles[idx],
        color="C1"
    )
    axs[1].plot(
        alphas,
        boundary_error_erm,        
        linestyle=linestyles[idx],
        color="C2"
    )


    # axs[1].errorbar(
    #     alphas,
    #     adversarial_error_erm,
    #     yerr=adversarial_error_erm_std,
        
    #     markersize=1,
    #     linestyle=linestyles[idx],
    #     color="C0"
    # )
    # axs[1].errorbar(
    #     alphas,
    #     generalization_error_erm,
    #     yerr=generalization_error_erm_std,
    #     markersize=1,
    #     linestyle=linestyles[idx],
    #     color="C1"
    # )
    # axs[1].errorbar(
    #     alphas,
    #     boundary_error_erm,
    #     yerr=boundary_error_erm_std,
        
    #     markersize=1,
    #     linestyle=linestyles[idx],
    #     color="C2"
    # )
    # axs[1].errorbar(
    #     alphas,
    #     class_preserving_erm,
    #     yerr=class_preserving_erm_std,
    #     fmt="*",
    #     markersize=1,
    #     color="C3"
    # )

axs[0].set_xscale("log")
axs[0].set_yscale("log")
axs[0].set_ylabel(r"$E$", labelpad=2.0)
# axs[0].set_xlabel(r"$\alpha$", labelpad=2.0)
axs[0].grid(which="both", axis="both", alpha=0.5)
axs[0].tick_params(axis='both', which='major', direction='in')
axs[0].tick_params(axis='both', which='minor', direction='in')
# axs[0].legend(title="State Evolution", loc="lower left")

axs[1].set_xscale("log")
axs[1].set_yscale("log")
axs[1].set_ylabel(r"$E$", labelpad=2.0)
axs[1].set_xlabel(r"$\alpha$", labelpad=2.0)
axs[1].grid(which="both", axis="both", alpha=0.5)
axs[1].tick_params(axis='both', which='major', direction='in')
axs[1].tick_params(axis='both', which='minor', direction='in')
# axs[1].legend(title="$\\boldsymbol{b}$", loc="lower left")



error_legend = []

error_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{adv}}$",color="C0"))
error_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{gen}}$",color="C1"))
error_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{bound}}$",color="C2"))
error_legend.append(Line2D([],[], color="white"))

epsilon_legend = []

for idx, epsilon in enumerate(epsilons):
    epsilon_legend.append(Line2D([0],[0],color="black", linestyle=linestyles[idx], label=r"$\varepsilon_t={}$".format(epsilons[idx]))) 

custom_legend = []

for idx in range(len(error_legend)):
    custom_legend.append(error_legend[idx])
    custom_legend.append(epsilon_legend[idx])

# fig.legend(handles=custom_legend, loc="upper center", ncol=4, handlelength=1.5)

save = True
if save:
    save_plot(
        fig,
        "effective_regularisation",
    )

plt.show()

plt.tight_layout()
# Out:
# Figure size:  (2.5, 2.4)
# Figure size:  [2.5 2.4]

# %%
# save the legend separately, put the custom legend into a figure
figlegend = plt.figure(figsize=( 4.25, 0.15*tuple_size[1]))
plt.style.use("../latex_ready.mplstyle")
legend_ax = figlegend.add_axes([0, 0, 1, 1])
legend_ax.axis('off')  # Turn off the axes for the legend figure

figlegend.legend(
    handles=custom_legend,
    handlelength=1,
    loc="center",
    ncol=4,
)

figlegend.savefig(
    os.path.join(IMG_DIRECTORY, "legend.pdf"),
    format="pdf",
    # bbox_inches="tight",
)


plt.show()

# %%
custom_legend = []

custom_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{adv}}$",color="C0"))
custom_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{gen}}$",color="C1"))
custom_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{bound}}$",color="C2"))
# custom_legend.append(Line2D([0],[0],label=r"$E_{\mathrm{CP}}$",color="C0", marker='o'))





# save the legend separately, put the custom legend into a figure
figlegend = plt.figure(figsize=( tuple_size[0], 0.1 * tuple_size[0]))
plt.style.use("../latex_ready.mplstyle")
legend_ax = figlegend.add_axes([0, 0, 1, 1])
legend_ax.axis('off')  # Turn off the axes for the legend figure

figlegend.legend(
    handles=custom_legend,
    handlelength=1,
    loc="center",
    ncol=5,
)

figlegend.savefig(
    os.path.join(IMG_DIRECTORY, "effective_regularisation_legend_error.pdf"),
    format="pdf",
    # bbox_inches="tight",
)


plt.show()

# %%
custom_legend = []

for idx, epsilon in enumerate(epsilons):
    custom_legend.append(Line2D([0],[0],color="black", linestyle=linestyles[idx], label=r"$\varepsilon_t={}$".format(epsilons[idx]))) 


# save the legend separately, put the custom legend into a figure
figlegend = plt.figure(figsize=( 1.2 * tuple_size[0],0.1 * tuple_size[0]))
plt.style.use("../latex_ready.mplstyle")
legend_ax = figlegend.add_axes([0, 0, 1, 1])
legend_ax.axis('off')  # Turn off the axes for the legend figure

figlegend.legend(
    handles=custom_legend,
    handlelength=2,
    loc="center",
    ncol=5,
)

figlegend.savefig(
    os.path.join(IMG_DIRECTORY, "effective_regularisation_legend_epsilon.pdf"),
    format="pdf",
    # bbox_inches="tight",
)


plt.show()
