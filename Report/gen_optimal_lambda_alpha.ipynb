# %%
import os
import inspect
import sys
sys.path.insert(0, "../")


from experiment_information import *
from data import *
from helpers import *
from _version import __version__
import seaborn as sns
import matplotlib.pyplot as plt



import pandas as pd
import numpy as np
import logging
import pprint
import re
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
# mpl.rcParams['lines.linewidth'] = 1
# mpl.rcParams['legend.fontsize'] = 13

# mpl.rcParams['axes.titlesize'] = 15
# mpl.rcParams['axes.labelsize'] = 13
# mpl.rcParams['xtick.labelsize'] = 10
# mpl.rcParams['ytick.labelsize'] = 10

# %%
from _version import __version__
df_experiments = None
df_state_evolution = None
df_erm = None
logger = logging.getLogger()
# with DatabaseHandler(logger,"experiments/experiments.db") as dbHandler:
with DatabaseHandler(logger,"../experiments/experiments.db") as dbHandler:

    df_experiments = dbHandler.get_experiments()
    df_state_evolution = dbHandler.get_state_evolutions()
    df_state_evolution["calibrations"] = df_state_evolution["calibrations"].apply(lambda x: json.loads(x))
    df_erm = dbHandler.get_erms()
    df_erm["analytical_calibrations"] = df_erm["analytical_calibrations"].apply(lambda x: json.loads(x))
    df_erm["erm_calibrations"] = df_erm["erm_calibrations"].apply(lambda x: json.loads(x))
    # delete incomplete experiments (bad, deletes running experiments...)
    # dbHandler.delete_incomplete_experiments()

# def explode_calibrations(df):
#     a = df["calibrations"].apply(pd.Series)
#     # drop the original calibrations column
#     df = df.drop(columns=["calibrations"])
#     # concat the original dataframe with the new dataframe containing the exploded calibrations column
#     df = pd.concat([df,a],axis=1)
#     # explode both calibrations and ps columns
#     df = df.explode(["calibrations","ps"])
#     # rename the exploded columns
#     df = df.rename(columns={"calibrations":"calibration","ps":"p_calibration"})
#     return df
# df_state_evolution = explode_calibrations(df_state_evolution)
# def explode_erm_calibrations(df):
#     a = df["erm_calibrations"].apply(pd.Series)
#     # drop the original calibrations column
#     df = df.drop(columns=["erm_calibrations"])
#     b = df["analytical_calibrations"].apply(pd.Series)
#     # drop the original calibrations column
#     df = df.drop(columns=["analytical_calibrations"])
#     # drop the dp and ps columns from b
#     b = b.drop(columns=["dp","ps"])
#     # rename the columns of b
#     b = b.rename(columns={"calibrations":"analytical_calibration"})
#     # rename the columns of a
#     a = a.rename(columns={"calibrations":"erm_calibration"})
#     # concat the original dataframe with the new dataframe containing the exploded calibrations column
#     df = pd.concat([df,a],axis=1)
#     df = pd.concat([df,b],axis=1)
#     # explode both calibrations and ps columns
#     df = df.explode(["erm_calibration","analytical_calibration","ps"])
#     # rename the exploded columns
#     df = df.rename(columns={"ps":"p_calibration"})
#     return df
# df_erm = explode_erm_calibrations(df_erm)

def explode_measures(df, new_columns, columns):
    for column in columns:
        def transform(column):
            # replace NaN in the column string by 0
            column = column.replace("NaN","0")
            # replace null in the column string by 0
            column = column.replace("null","0")
            # replace Infinity in the column string by np.inf
            column = column.replace("Infinity","np.inf")
            return eval(column)
        df[column] = df[column].apply(transform)

    exploded = df.explode(columns).reset_index(drop=True)

    for new_column, column in zip(new_columns, columns):
        if len(exploded[column].tolist()) > 0:
            exploded[["attack_epsilon",new_column]] = pd.DataFrame(exploded[column].tolist(), index=exploded.index)
        else:
            exploded[new_column] = np.nan
            # set attack_epsilon
            exploded["attack_epsilon"] = np.nan

    exploded = exploded.drop(columns=columns)
    return exploded

def explode_erm_measures(df):
    columns = ["adversarial_generalization_errors","adversarial_generalization_errors_teacher","adversarial_generalization_errors_overlap","fair_adversarial_errors","test_losses","boundary_loss_test_es"]
    new_columns = ["adversarial_generalization_error","adversarial_generalization_error_teacher","adversarial_generalization_error_overlap","fair_adversarial_error","test_loss","boundary_loss_test"]
    return explode_measures(df, new_columns, columns)

def explode_state_evolution_measures(df):
    columns = ["adversarial_generalization_errors","adversarial_generalization_errors_teacher","fair_adversarial_errors","first_term_fair_errors","second_term_fair_errors","third_term_fair_errors","test_losses","data_model_adversarial_generalization_errors","gamma_robustness_es","boundary_loss_test_es"]
    new_columns = ["adversarial_generalization_error","adversarial_generalization_error_teacher","fair_adversarial_error","first_term_fair_error","second_term_fair_error","third_term_fair_error","test_loss","data_model_adversarial_generalization_error","gamma_robustness","boundary_loss_test"] #
    # columns = ["adversarial_generalization_errors","adversarial_generalization_errors_teacher","fair_adversarial_errors","second_term_fair_errors","test_losses","data_model_adversarial_generalization_errors"]
    # new_columns = ["adversarial_generalization_error","adversarial_generalization_error_teacher","fair_adversarial_error","second_term_fair_error","test_loss","data_model_adversarial_generalization_error"] #
    return explode_measures(df, new_columns, columns)
    

df_erm = explode_erm_measures(df_erm)

df_state_evolution = explode_state_evolution_measures(df_state_evolution)
    

print("Current code version, ", __version__)
# Out:
# Current code version,  101

# %%
def extract_first_eigenvalue(row, column):
    array = row[column]

    # load json string to array
    array = json.loads(array)
    return np.array([float(array[0])])
def extract_second_eigenvalue(row, column):
    array = row[column]

    # load json string to array
    array = json.loads(array)
    return np.array([float(array[-1])])
def extract_trace(row, column):
    array = row[column]

    # load json string to array
    array = json.loads(array)
    return np.array([float(sum(array))])

df2 = df_state_evolution.reset_index()


df2["sigmax_first_ev"] = df2.apply(lambda row: extract_first_eigenvalue(row, "sigmax_eigenvalues"), axis=1)
df2["sigmax_second_ev"] = df2.apply(lambda row: extract_second_eigenvalue(row, "sigmax_eigenvalues"), axis=1)
df2["sigmax_trace"] = df2.apply(lambda row: extract_trace(row, "sigmax_eigenvalues"), axis=1)

df2["sigmatheta_first_ev"] = df2.apply(lambda row: extract_first_eigenvalue(row, "sigmatheta_eigenvalues"), axis=1)
df2["sigmatheta_second_ev"] = df2.apply(lambda row: extract_second_eigenvalue(row, "sigmatheta_eigenvalues"), axis=1)
df2["sigmatheta_trace"] = df2.apply(lambda row: extract_trace(row, "sigmatheta_eigenvalues"), axis=1)

df2["xtheta_first_ev"] = df2.apply(lambda row: extract_first_eigenvalue(row, "xtheta_eigenvalues"), axis=1)
df2["xtheta_second_ev"] = df2.apply(lambda row: extract_second_eigenvalue(row, "xtheta_eigenvalues"), axis=1)
df2["xtheta_trace"] = df2.apply(lambda row: extract_trace(row, "xtheta_eigenvalues"), axis=1)

# columns = ["sigmax_first_ev","sigmax_second_ev","sigmax_trace","sigmatheta_first_ev","sigmatheta_second_ev","sigmatheta_trace","xtheta_first_ev","xtheta_second_ev","xtheta_trace"]

# for column in columns:
#     # apply mean and std to the new column
#     df_result = df2[column].apply(lambda x: pd.Series({"mean":x, "std":0}))
#     multiindex = pd.MultiIndex.from_product([[column], ['mean', 'std']], names=['', ''])
#     df_result.columns = multiindex
#     # Concatenate the original DataFrame with the computed values DataFrame
#     df2 = pd.concat([df2, df_result], axis=1)

# drop the original eigenvalues columns
df2 = df2.drop(columns=["sigmax_eigenvalues","sigmatheta_eigenvalues","xtheta_eigenvalues"])

df_state_evolution = df2

# df_state_evolution

# %%
# get the completed experiments with the current code version ordered by date
version_choice = __version__
version_choice = "100"
df_experiments = df_experiments[(df_experiments["completed"]==True) & (df_experiments["code_version"]==version_choice)]
df_experiments = df_experiments.sort_values(by="date",ascending=False)
df_experiments.head(3)
# Out:
#                            experiment_id experiment_name    duration  \
# 72  e2e06001-5fb9-45a9-b24c-13ced10b08ce  OptimalDefense  220.073220
# 71  04a8c1fc-9044-4473-bbbf-bb67048f670a  OptimalDefense   58.451196
# 70  5a037c7b-4d09-472a-9a06-2670e5c0cd17  OptimalDefense    2.717105
#
#    problem_types code_version                 date  \
# 72  ["Logistic"]          100  2024-01-31 06:02:30
# 71  ["Logistic"]          100  2024-01-31 05:57:00
# 70  ["Logistic"]          100  2024-01-31 05:54:11
#
#     state_evolution_repetitions  erm_repetitions alphas  \
# 72                            1               20   [20]
# 71                            1                5   [20]
# 70                            1                0   [20]
#
#                                              epsilons  ...   taus    ps    dp  \
# 72  [0.001, 0.0011, 0.0013, 0.0015, 0.0017, 0.002,...  ...  [0.0]  null  0.01
# 71  [0.001, 0.0011, 0.0013, 0.0015, 0.0017, 0.002,...  ...  [0.0]  null  0.01
# 70  [0.005, 0.0054, 0.0059, 0.0064, 0.0069, 0.0075...  ...  [0.0]  null  0.01
#
#        d  experiment_type  completed                      data_model_types  \
# 72  1000            Sweep          1  ["KFeaturesModel", "KFeaturesModel"]
# 71  1000            Sweep          1  ["KFeaturesModel", "KFeaturesModel"]
# 70  1000            Sweep          1  ["KFeaturesModel", "KFeaturesModel"]
#
#                                      data_model_names  \
# 72  ["KFeaturesModel_TeacherDefense_TeacherAttacke...
# 71  ["KFeaturesModel_TeacherDefense_TeacherAttacke...
# 70  ["KFeaturesModel_TeacherDefense_TeacherAttacke...
#
#                               data_model_descriptions gamma_fair_error
# 72  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
# 71  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
# 70  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
#
# [3 rows x 22 columns]

# %%
df_state_evolution["estimation_error"] = 1 + df_state_evolution["q"] - 2 * df_state_evolution["m"]

# %%
experiment_loc = 0

# extract experiment by id "250fa46e-55cb-40d2-b503-11b38823235d"
# experiment_id = "d43ae27a-cf92-4261-a7d1-de5c9717f775"


# extract and print the top experiment_id
experiment_id = df_experiments.iloc[experiment_loc]["experiment_id"]
print(experiment_id)

# extract and print the experiment type
experiment_type = df_experiments.iloc[experiment_loc]["experiment_type"]
print(experiment_type)

# extract and print the data model type and data_model name used
data_model_types = df_experiments.iloc[experiment_loc]["data_model_types"]
# convert it to the enum
data_model_types = [DataModelType[data_model_type] for data_model_type in json.loads(data_model_types)]
data_model_names = [name for name in json.loads(df_experiments.iloc[experiment_loc]["data_model_names"])]
data_model_descriptions = df_experiments.iloc[experiment_loc]["data_model_descriptions"]
for data_model_type in data_model_types:
    print(data_model_type.name)
print(data_model_names)
print(data_model_descriptions)

# print the experiment name
experiment_name = df_experiments.iloc[experiment_loc]["experiment_name"]
print(experiment_name)

# print the experiment problem types
experiment_problem_types = df_experiments.iloc[experiment_loc]["problem_types"]
experiment_problem_types = json.loads(experiment_problem_types)
print(experiment_problem_types)
# Out:
# e2e06001-5fb9-45a9-b24c-13ced10b08ce
# Sweep
# KFeaturesModel
# KFeaturesModel
# ['KFeaturesModel_TeacherDefense_TeacherAttacked___OptimalDefense', 'KFeaturesModel_OrthogonalDefense_OrthogonalAttacked___OptimalDefense']
# ["2 Features, Theta Identity, Sigma_upsilon Identity, Sigma_delta Identity", "2 Features, Theta Identity, Sigma_upsilon Identity, Sigma_delta Identity"]
# OptimalDefense
# ['Logistic']

# %%
data_model_name_dict = {}
data_model_name_dict["VanillaGaussian"] = "Vanilla Gaussian"
data_model_name_dict["2_VanillaGaussian"] = "Vanilla Gaussian"
data_model_name_dict["VanillaGaussianThetaFirst"] = "Vanilla Gaussian - Teacher 10:1"
data_model_name_dict["VanillaGaussianTimes10"] = "Vanilla Gaussian x10"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[1 1]"] = "Strong Weak 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[1 1]"] = "Strong Weak 5:1"
data_model_name_dict["2_KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[1 1]"] = "Strong Weak 5:1"
data_model_name_dict["2_KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[1 1]"] = "Strong Weak 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[10  1]"] = "Strong Weak 5:1 - Teacher 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[10  1]"] = "Strong Weak 10:1 - Teacher 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[ 1 10]"] = "Strong Weak 5:1 - Teacher 1:10"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[ 1 10]"] = "Strong Weak 10:1 - Teacher 1:10"

# %%
state_evolution = df_state_evolution[df_state_evolution["experiment_id" ] == experiment_id]
gd = df_erm[df_erm["experiment_id" ] == experiment_id]
# make the column subspace_overlaps to string
state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: str(x))
gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: str(x))

# create a json colum
state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: json.loads(x))
gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: json.loads(x))
from pandas import json_normalize
# normalize the json column
normalized = json_normalize(state_evolution["subspace_overlaps"])
normalized_gd = json_normalize(gd["subspace_overlaps"])



def explode_array_column(row, col):
    return pd.Series(row[col])

# reset the index of the original dataframe
state_evolution = state_evolution.reset_index(drop=True)
gd = gd.reset_index(drop=True)

for col in normalized.columns:
    expanded_cols = normalized.apply(lambda x: explode_array_column(x,col), axis=1)
    col = col[:-1]
    expanded_cols.columns = [col+'_{}'.format(i) for i in range(expanded_cols.shape[1])]
    # reset the index of the expanded columns
    expanded_cols = expanded_cols.reset_index(drop=True)
    state_evolution = pd.concat([state_evolution, expanded_cols], axis=1)

for col in normalized_gd.columns:
    expanded_cols = normalized_gd.apply(lambda x: explode_array_column(x,col), axis=1)
    col = col[:-1]
    expanded_cols.columns = [col+'_{}'.format(i) for i in range(expanded_cols.shape[1])]
    # reset the index of the expanded columns
    expanded_cols = expanded_cols.reset_index(drop=True)

    gd = pd.concat([gd, expanded_cols], axis=1)
# Out:
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_24886/3541688095.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: str(x))
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_24886/3541688095.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: str(x))
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_24886/3541688095.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: json.loads(x))
# /var/folders/4p/9b_m1n3130xfbjd06qfyyqgc0000gn/T/ipykernel_24886/3541688095.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: json.loads(x))

# %%
state_evolution["subspace_overlaps_ratio"] = state_evolution["subspace_overlaps_ratio"].apply(lambda x: str(x))
state_evolution["subspace_overlaps_ratio"] = state_evolution["subspace_overlaps_ratio"].apply(lambda x: json.loads(x))
normalized = json_normalize(state_evolution["subspace_overlaps_ratio"])
# rename the columns of the normalized dataframe
for column in normalized.columns:
    normalized = normalized.rename(columns={column:column+"_ratio"})
# merge the normalized dataframe with the original dataframe
state_evolution = pd.concat([state_evolution, normalized], axis=1)
# drop the original subspace_overlaps column
state_evolution = state_evolution.drop(columns=["subspace_overlaps_ratio"])

gd["subspace_overlaps_ratio"] = gd["subspace_overlaps_ratio"].apply(lambda x: str(x))
gd["subspace_overlaps_ratio"] = gd["subspace_overlaps_ratio"].apply(lambda x: json.loads(x))
normalized = json_normalize(gd["subspace_overlaps_ratio"])
# rename the columns of the normalized dataframe
for column in normalized.columns:
    normalized = normalized.rename(columns={column:column+"_ratio"})
# merge the normalized dataframe with the original dataframe
gd = pd.concat([gd, normalized], axis=1)
# drop the original subspace_overlaps column
gd = gd.drop(columns=["subspace_overlaps_ratio"])

# %%
# create a column for the difference between the adversarial_generalization_error and the generalization_error for both the state evolution and the erm
state_evolution["difference_adv_gen"] = state_evolution["adversarial_generalization_error"] - state_evolution["generalization_error"]
gd["difference_adv_gen"] = gd["adversarial_generalization_error"] - gd["generalization_error_erm"]


state_evolution["ratio_adv_gen"] = state_evolution["adversarial_generalization_error"] / state_evolution["generalization_error"]
gd["ratio_adv_gen"] = gd["adversarial_generalization_error"] / gd["generalization_error_erm"]

# %%
# create a column for the noise contribution
def noise_contribution(rho: float, tau: float) -> float:
    if tau == 0:
        tau = 1e-10
    return 0.5 - np.arctan( np.sqrt( rho / tau**2 ) ) / np.pi

state_evolution["noise_contribution"] = state_evolution.apply(lambda x: noise_contribution(x["rho"], x["tau"]), axis=1)
gd["noise_contribution"] = gd.apply(lambda x: noise_contribution(x["rho"], x["tau"]), axis=1)

# %%
# create a column for the noiseless generalization error without the noise contribution
state_evolution["noiseless_generalization_error"] = state_evolution["generalization_error"] - state_evolution["noise_contribution"]
gd["noiseless_generalization_error_erm"] = gd["generalization_error_erm"] - gd["noise_contribution"]

# create a column for the adversarial noiseless generalization error without the noise contribution
state_evolution["noiseless_adversarial_generalization_error"] = state_evolution["adversarial_generalization_error"] - state_evolution["noise_contribution"]
gd["noiseless_adversarial_generalization_error"] = gd["adversarial_generalization_error"] - gd["noise_contribution"]

# %%
# create a column for the A/sqrt(q*N) for both the state evolution and the erm
state_evolution["A_over_sqrt_qN"] = state_evolution["A"] / np.sqrt(state_evolution["q"] * state_evolution["N"])
gd["A_over_sqrt_qN"] = gd["A"] / np.sqrt(gd["q"] * gd["N"])

# %%
# create a column for m/sqrt( rho*q - m**2 ) vs A/sqrt(q*N) for both the state evolution and the erm
state_evolution["m_over_sqrt_rhoq_minus_m2"] = state_evolution["m"] / np.sqrt(state_evolution["rho"] * state_evolution["q"] - state_evolution["m"]**2)
gd["m_over_sqrt_rhoq_minus_m2"] = gd["m"] / np.sqrt(gd["rho"] * gd["q"] - gd["m"]**2)

# %%
# strip the data_model_name if there is a sequence ___text at the end
def strip_data_model_name(data_model_name):
    return re.sub(r"___.*","",data_model_name)
state_evolution["data_model_name"] = state_evolution["data_model_name"].apply(strip_data_model_name)
gd["data_model_name"] = gd["data_model_name"].apply(strip_data_model_name)

# %%
gd = gd.set_index(["alpha","epsilon","tau","lam","problem_type","attack_epsilon","data_model_name"]) #,"p_calibration"
state_evolution = state_evolution.set_index(["alpha","epsilon","tau","lam","problem_type","attack_epsilon","data_model_name"]) #,"p_calibration"

# drop id, code_version, experiment_id, date, initial_condition, test_against_epsilons, calibrations, abs_tol, min_iter,max_iter,blend_fpe,int_lims,subspace_overlaps
state_evolution = state_evolution.drop(columns=["id","code_version","experiment_id","date","initial_condition","test_against_epsilons","calibrations","abs_tol","min_iter","max_iter","blend_fpe","int_lims","subspace_overlaps","data_model_type","data_model_description"])
# drop id, code_version, experiment_id, test_against_epsilons, date, subspace_overlaps, analytical_calibrations, erm_calibrations, 
gd = gd.drop(columns=["id","code_version","experiment_id","test_against_epsilons","date","subspace_overlaps","analytical_calibrations","erm_calibrations","data_model_type","data_model_description"])

state_evolution.columns = [col+"_state_evolution" for col in state_evolution.columns]
gd.columns = [col+"_erm" for col in gd.columns]

state_evolution = state_evolution.groupby(level=[0,1,2,3,4,5,6]).agg(["mean","std"]) #,4
gd = gd.groupby(level=[0,1,2,3,4,5,6]).agg(["mean","std"]) #,4
df = state_evolution.join(gd, how="outer")
df.sort_index()
df
# Out:
#                                                                                                        index_state_evolution  \
#                                                                                                                         mean
# alpha epsilon tau lam   problem_type attack_epsilon data_model_name
# 20.0  0.0010  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5143.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5114.0
#       0.0011  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5144.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5113.0
#       0.0013  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5145.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5115.0
#       0.0015  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5146.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5116.0
#       0.0017  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5147.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5117.0
#       0.0020  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5148.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5118.0
#       0.0022  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5149.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5119.0
#       0.0026  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5150.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5120.0
#       0.0029  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5151.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5121.0
#       0.0034  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5152.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5122.0
#       0.0039  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5153.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5123.0
#       0.0044  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5154.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5124.0
#       0.0051  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5155.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5125.0
#       0.0058  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5156.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5126.0
#       0.0066  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5157.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5127.0
#       0.0076  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5158.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5128.0
#       0.0087  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5159.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5129.0
#       0.0099  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5160.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5130.0
#       0.0114  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5161.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5131.0
#       0.0130  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5162.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5132.0
#       0.0149  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5163.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5133.0
#       0.0170  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5164.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5134.0
#       0.0195  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5165.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5135.0
#       0.0223  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5166.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5136.0
#       0.0255  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5167.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5137.0
#       0.0292  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5168.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5138.0
#       0.0334  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5169.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5139.0
#       0.0383  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5170.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5140.0
#       0.0438  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5171.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5141.0
#       0.0501  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                5172.0
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     5142.0
#
#                                                                                                             \
#                                                                                                        std
# alpha epsilon tau lam   problem_type attack_epsilon data_model_name
# 20.0  0.0010  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0011  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0013  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0015  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0017  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0020  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0022  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0026  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0029  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0034  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0039  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0044  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0051  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0058  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0066  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0076  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0087  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0099  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0114  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0130  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0149  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0170  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0195  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0223  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0255  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0292  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0334  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0383  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0438  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0501  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#
#                                                                                                        duration_state_evolution  \
#                                                                                                                            mean
# alpha epsilon tau lam   problem_type attack_epsilon data_model_name
# 20.0  0.0010  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 9.702201
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                     10.238665
#       0.0011  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 7.486316
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      9.887313
#       0.0013  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 8.126834
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      8.504375
#       0.0015  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 6.464857
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      7.020964
#       0.0017  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 4.436682
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      5.779657
#       0.0020  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 3.559241
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      4.298302
#       0.0022  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 3.217549
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      2.845907
#       0.0026  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 3.882607
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      2.028081
#       0.0029  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 2.378483
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      3.079247
#       0.0034  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 2.082590
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.280661
#       0.0039  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 2.978322
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      2.311167
#       0.0044  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.670252
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.874863
#       0.0051  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.634212
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.867720
#       0.0058  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.423336
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.886142
#       0.0066  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.320397
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.658847
#       0.0076  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.272102
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.728564
#       0.0087  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.273807
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      0.258864
#       0.0099  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 2.515118
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.671568
#       0.0114  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 2.636063
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      0.300274
#       0.0130  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.061052
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.384870
#       0.0149  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.034002
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.620763
#       0.0170  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.067454
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.333639
#       0.0195  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.076160
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.652479
#       0.0223  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 0.995731
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      0.194038
#       0.0255  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 1.059287
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      0.205131
#       0.0292  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 2.286789
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      0.244357
#       0.0334  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 0.952376
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.517730
#       0.0383  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 0.936814
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.367866
#       0.0438  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 0.917804
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      0.174095
#       0.0501  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                 0.947050
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                      1.195804
#
#                                                                                                             \
#                                                                                                        std
# alpha epsilon tau lam   problem_type attack_epsilon data_model_name
# 20.0  0.0010  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0011  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0013  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0015  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0017  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0020  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0022  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0026  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0029  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0034  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0039  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0044  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0051  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0058  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0066  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0076  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0087  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0099  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0114  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0130  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0149  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0170  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0195  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0223  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0255  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0292  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0334  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0383  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0438  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0501  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#
#                                                                                                        generalization_error_state_evolution  \
#                                                                                                                                        mean
# alpha epsilon tau lam   problem_type attack_epsilon data_model_name
# 20.0  0.0010  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.034693
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.026018
#       0.0011  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.036919
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.026790
#       0.0013  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.041476
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.028506
#       0.0015  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.045961
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.030410
#       0.0017  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.050205
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.032478
#       0.0020  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.055957
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.035883
#       0.0022  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.059360
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.038375
#       0.0026  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.065207
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.044008
#       0.0029  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.068870
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.048927
#       0.0034  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.073888
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.058838
#       0.0039  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.077870
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.071500
#       0.0044  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.081088
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.087619
#       0.0051  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.084667
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.116580
#       0.0058  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.087471
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.150586
#       0.0066  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.090010
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.188004
#       0.0076  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.092484
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.225420
#       0.0087  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.094587
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.255493
#       0.0099  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.096374
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.279388
#       0.0114  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.098102
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.301110
#       0.0130  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.099520
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.318079
#       0.0149  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.100821
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.333049
#       0.0170  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.101929
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.345423
#       0.0195  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.102943
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.356491
#       0.0223  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.103815
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.365824
#       0.0255  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.104580
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.373906
#       0.0292  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.105259
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.380995
#       0.0334  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.105850
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.387109
#       0.0383  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.106377
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.392528
#       0.0438  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.106829
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.397155
#       0.0501  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                             0.107226
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                                  0.401199
#
#                                                                                                             \
#                                                                                                        std
# alpha epsilon tau lam   problem_type attack_epsilon data_model_name
# 20.0  0.0010  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0011  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0013  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0015  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0017  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0020  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0022  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0026  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0029  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0034  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0039  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0044  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0051  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0058  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0066  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0076  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0087  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0099  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0114  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0130  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0149  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0170  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0195  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0223  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0255  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0292  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0334  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0383  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0438  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#       0.0501  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta... NaN
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked      NaN
#
#                                                                                                        training_loss_state_evolution  \
#                                                                                                                                 mean
# alpha epsilon tau lam   problem_type attack_epsilon data_model_name
# 20.0  0.0010  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      0.074513
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.083824
#       0.0011  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      0.080832
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.094256
#       0.0013  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      0.092233
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.115617
#       0.0015  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      0.101970
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.137150
#       0.0017  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      0.110215
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.158550
# ...
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked        0.009713
#
#                                                                                                        m_over_sqrt_rhoq_minus_m2_erm  \
#                                                                                                                                 mean
# alpha epsilon tau lam   problem_type attack_epsilon data_model_name
# 20.0  0.0010  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                     11.090500
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                          12.220458
#       0.0011  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                     11.276280
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                          11.917305
#       0.0013  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                     11.090536
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                          11.390488
#       0.0015  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      8.777066
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                          10.554222
#       0.0017  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      9.146814
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           9.795386
#       0.0020  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      9.585164
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           8.924386
#       0.0022  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      7.914217
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           8.338365
#       0.0026  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      8.481562
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           7.274769
#       0.0029  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      7.218415
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           6.476563
#       0.0034  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      7.337106
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           5.404311
#       0.0039  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      7.821242
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           4.447797
#       0.0044  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      6.269380
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           3.636469
#       0.0051  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      6.930111
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           2.708685
#       0.0058  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      5.487296
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           2.012911
#       0.0066  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      8.530312
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           1.509085
#       0.0076  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      5.021208
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           1.191247
#       0.0087  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      6.003406
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.977023
#       0.0099  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      6.155638
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.843395
#       0.0114  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      6.029866
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.763232
#       0.0130  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      5.215432
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.698043
#       0.0149  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      5.408378
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.629326
#       0.0170  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      4.274938
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.580202
#       0.0195  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      4.955745
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.508131
#       0.0223  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      5.772400
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.492326
#       0.0255  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      6.846789
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.469347
#       0.0292  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      5.015859
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.425303
#       0.0334  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      7.137911
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.426823
#       0.0383  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      5.560445
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.386471
#       0.0438  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      4.761051
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.373563
#       0.0501  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...                      4.242902
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked                           0.317056
#
#
#                                                                                                              std
# alpha epsilon tau lam   problem_type attack_epsilon data_model_name
# 20.0  0.0010  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.134420
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.301642
#       0.0011  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.382485
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.392674
#       0.0013  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.567602
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.397718
#       0.0015  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.256801
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.225081
#       0.0017  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.972723
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.310699
#       0.0020  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.593667
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.308353
#       0.0022  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.108298
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.376425
#       0.0026  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.839940
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.432968
#       0.0029  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.970937
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.181295
#       0.0034  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.141625
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.158464
#       0.0039  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.179555
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.253672
#       0.0044  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.522718
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.241751
#       0.0051  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.617736
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.384133
#       0.0058  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.474062
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.211939
#       0.0066  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.913781
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.143267
#       0.0076  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.429275
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.142046
#       0.0087  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.869744
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.122731
#       0.0099  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.167077
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.150792
#       0.0114  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.650032
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.078096
#       0.0130  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.854193
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.129629
#       0.0149  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  2.694051
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.107380
#       0.0170  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  2.296377
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.085729
#       0.0195  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.976551
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.096151
#       0.0223  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.029260
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.134862
#       0.0255  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.027441
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.117014
#       0.0292  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.745048
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.110935
#       0.0334  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.624912
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.066120
#       0.0383  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.723079
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.135551
#       0.0438  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  4.456734
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.109124
#       0.0501  0.0 0.001 Logistic     0.006          KFeaturesModel_OrthogonalDefense_OrthogonalAtta...  3.631016
#                                                     KFeaturesModel_TeacherDefense_TeacherAttacked       0.066424
#
# [60 rows x 248 columns]

# %%
# store the dataframe as a pickle file
if not os.path.exists("Pickles"):
    os.makedirs("Pickles")
if not os.path.exists("Pickles/gen_optimal_lam_alpha.pkl"):
    df.to_pickle("Pickles/gen_optimal_lam_alpha.pkl")

# %%
# load the dataframe from the pickle file
df = pd.read_pickle("Pickles/gen_optimal_lam_alpha.pkl")

# %% [markdown]
# # extracting the data

# %%
# get unique epsilons
epsilons = df.index.get_level_values(1).unique()
epsilons
# Out:
# Index([0.0, 0.1, 0.2], dtype='float64', name='epsilon')

# %%
# get unique attack_epsilons
attack_epsilons = df.index.get_level_values(5).unique()
attack_epsilons
# Out:
# Index([0.2], dtype='float64', name='attack_epsilon')

# %%
# create a dictionary of dataframes for each data_model_name
epsilon_dict = {}
for epsilon in epsilons:

    eps_df = df.xs(epsilon, level="epsilon")

    

    

    alphas = eps_df.index.get_level_values("alpha").unique()
    adversarial_error_0 = eps_df["adversarial_generalization_error_state_evolution"]["mean"].values
    generalization_error_0 = eps_df["generalization_error_state_evolution"]["mean"].values
    boundary_error_0 = eps_df["difference_adv_gen_state_evolution"]["mean"].values

    alphas = np.array(alphas)
    adversarial_error_0 = np.array(adversarial_error_0)
    generalization_error_0 = np.array(generalization_error_0)
    boundary_error_0 = np.array(boundary_error_0)

    eps_0_dict = {}
    eps_0_dict["alphas"] = alphas
    eps_0_dict["adversarial_error"] = adversarial_error_0
    eps_0_dict["generalization_error"] = generalization_error_0
    eps_0_dict["boundary_error"] = boundary_error_0


    epsilon_dict[epsilon] = eps_0_dict

# %%
np.argmin(epsilon_dict[0.2]["generalization_error"])
# Out:
# 5

# %% [markdown]
# # Figure saving

# %%
IMG_DIRECTORY = "./Assets/gen_optimal_lambda_alpha"
if not os.path.exists(IMG_DIRECTORY):
    os.makedirs(IMG_DIRECTORY)


def save_plot(fig, name, formats=["pdf","jpg"], date=False):
    current_date = datetime.datetime.now().strftime("%Y-%m-%d")
    for f in formats:        
        path = "{}".format(name) + "_{}".format(current_date) + "." + f
        if not date:
            path = "{}".format(name) + "." + f
        fig.savefig(            
            os.path.join(IMG_DIRECTORY, path),
            format=f,
        )


def set_size(width, fraction=1, subplots=(1, 1)):
    if width == "thesis":
        width_pt = 426.79135
    elif width == "beamer":
        width_pt = 307.28987
    else:
        width_pt = width

    fig_width_pt = width_pt * fraction
    inches_per_pt = 1 / 72.27

    golden_ratio = (5**0.5 - 1) / 2

    fig_width_in = fig_width_pt * inches_per_pt
    fig_height_in = fig_width_in * (golden_ratio) * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)


width = 1.75 * 458.63788

plt.style.use("../latex_ready.mplstyle")

tuple_size = set_size(width, fraction=0.50)
tuple_size = (1.75 , 2.4)

multiplier = 0.9
second_multiplier = 0.35

fig, axs = plt.subplots(
    nrows=1,
    ncols=1,
    sharex=True,
    figsize=( tuple_size[0],  tuple_size[1]),
    gridspec_kw={"hspace": 0},
)

# print the figure size
print("Figure size: ", fig.get_size_inches())


# ICML adjustments
fig.subplots_adjust(left=0.33)
fig.subplots_adjust(bottom=0.12)
fig.subplots_adjust(top=0.97)
fig.subplots_adjust(right=0.99)

linestyles = ["solid", "dashed", "dashdot", "dotted"]

for idx, (epsilon, eps_dict) in enumerate(epsilon_dict.items()):


    alphas = eps_dict["alphas"]
    adversarial_error = eps_dict["adversarial_error"]
    generalization_error = eps_dict["generalization_error"]
    boundary_error = eps_dict["boundary_error"]


    # axs.plot(lams, adversarial_error, label=r"$E_{\mathrm{adv}}$", color="C0", linestyle=linestyles[idx])
    axs.plot(alphas, generalization_error, color="C1", linestyle=linestyles[idx])
    # axs.plot(lams, boundary_error, label=r"$E_{\mathrm{bound}}$", color="C2", linestyle=linestyles[idx])



# axs.set_xscale("log")
axs.set_yscale("log")
axs.set_ylabel(r"$E_{\mathrm{gen}}$", labelpad=2.0)
axs.set_xlabel(r"$\alpha$", labelpad=2.0)
axs.grid(which="both", axis="both", alpha=0.5)
axs.tick_params(axis="both", which="major", direction="in")
axs.tick_params(axis="both", which="minor", direction="in")

# axs.legend(title="$\\boldsymbol{a}$",loc="lower left")

# axs.ticklabel_format(axis="y", style='sci', scilimits=(-2, 2))
# make the y axis not have number*10^-1, but number with the scale 10^-1
axs.yaxis.set_major_formatter(mpl.ticker.FormatStrFormatter('%.4f'))
axs.yaxis.set_minor_formatter(mpl.ticker.FormatStrFormatter('%.4f'))

from matplotlib.lines import Line2D

epsilon_legend = []

for idx, epsilon in enumerate(epsilons):
    epsilon_legend.append(Line2D([0],[0],color="C1", linestyle=linestyles[idx], label=r"$\varepsilon_t={}$".format(epsilons[idx]))) 

# fig.legend(handles=epsilon_legend, loc="upper center", ncol=4, handlelength=1.5)



# plt.tight_layout()

save = True
if save:
    save_plot(
        fig,
        "gen_lambda_optimal_sweep_alpha",
    )

plt.show()
# Out:
# Figure size:  [1.75 2.4 ]
