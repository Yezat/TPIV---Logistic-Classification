# %%
import sys
sys.path.insert(0, "../")
sys.path.insert(0, "../experiments")


from experiment_information import *
from experiment_setup import *
from data import *
from helpers import *
from data_loading import *
import matplotlib.pyplot as plt



import pandas as pd
import numpy as np
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)


import numpy as np
import re
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# This code assumes that you have defined and run an experiment before using `define_experiment.ipynb` in the `experiments` folder.

# %%
df_experiments, df_state_evolution, df_erm = obtain_dataframes(logger)
df_experiments.head(5)
# Out:
# Current code version, 113
#                            experiment_id                    experiment_name  \
# 33  ed1bfdad-23b3-4929-9601-7126e6fea410               SweepAtOptimalLambda
# 31  f2ad5999-006a-489c-88e4-f924985ee46c  FeatureComparisonsTestOneSubspace
# 30  042b0fbb-4850-40c4-9dcd-9588e97e6471  FeatureComparisonsTestOneSubspace
# 29  7b24b808-04ae-43fc-b7aa-915d8f5978eb                     OptimalDefense
# 28  5d1a0552-f9e3-4c29-a0ec-6cf0e8026939                     OptimalDefense
#
#       duration problem_types code_version                 date  \
# 33   47.452392  ["Logistic"]          113  2024-06-19 11:51:05
# 31  417.302198  ["Logistic"]          113  2024-06-17 12:07:56
# 30   22.619816  ["Logistic"]          113  2024-06-17 11:47:24
# 29   12.160757  ["Logistic"]          113  2024-06-17 10:59:59
# 28   30.573092  ["Logistic"]          113  2024-06-17 10:53:17
#
#     state_evolution_repetitions  erm_repetitions  \
# 33                            1               10
# 31                            1               10
# 30                            1                0
# 29                            1                0
# 28                            1                0
#
#                                                alphas  \
# 33  [4.0, 4.0526, 4.1053, 4.1579, 4.2105, 4.2632, ...
# 31  [0.1585, 0.2154, 0.2929, 0.3981, 0.5412, 0.735...
# 30  [0.1585, 0.2154, 0.2929, 0.3981, 0.5412, 0.735...
# 29                                          [10000.0]
# 28                                          [10000.0]
#
#                                              epsilons  ...    taus    ps  \
# 33                               [0.0, 0.1, 0.2, 0.3]  ...  [0.05]  null
# 31                               [0.0, 0.1, 0.2, 0.3]  ...  [0.05]  null
# 30                               [0.0, 0.1, 0.2, 0.3]  ...  [0.05]  null
# 29  [0.01, 0.0105, 0.011, 0.0115, 0.0121, 0.0126, ...  ...   [0.1]  null
# 28  [0.001, 0.0011, 0.0012, 0.0013, 0.0015, 0.0016...  ...   [0.1]  null
#
#       dp     d       experiment_type  completed  \
# 33  0.01   500  SweepAtOptimalLambda          1
# 31  0.01   500                 Sweep          1
# 30  0.01   500                 Sweep          1
# 29  0.01  1000                 Sweep          1
# 28  0.01  1000                 Sweep          1
#
#                                      data_model_types  \
# 33                                 ["KFeaturesModel"]
# 31  ["KFeaturesModel", "KFeaturesModel", "KFeature...
# 30  ["KFeaturesModel", "KFeaturesModel", "KFeature...
# 29               ["KFeaturesModel", "KFeaturesModel"]
# 28               ["KFeaturesModel", "KFeaturesModel"]
#
#                                      data_model_names  \
# 33  ["KFeaturesModel_TwoFeatures_ProtectingSecondS...
# 31  ["KFeaturesModel_TwoFeatures_ProtectingSecondS...
# 30  ["KFeaturesModel_TwoFeatures_ProtectingSecondS...
# 29  ["KFeaturesModel_TeacherDefense_TeacherAttacke...
# 28  ["KFeaturesModel_TeacherDefense_TeacherAttacke...
#
#                               data_model_descriptions gamma_fair_error
# 33  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
# 31  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
# 30  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
# 29  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
# 28  ["2 Features, Theta Identity, Sigma_upsilon Id...           0.0001
#
# [5 rows x 22 columns]

# %%
experiment_loc = 0

# extract experiment by id "250fa46e-55cb-40d2-b503-11b38823235d"
# experiment_id = "d43ae27a-cf92-4261-a7d1-de5c9717f775"


# extract and print the top experiment_id
experiment_id = df_experiments.iloc[experiment_loc]["experiment_id"]
print(experiment_id)

# extract and print the experiment type
experiment_type = df_experiments.iloc[experiment_loc]["experiment_type"]
print(experiment_type)

# extract and print the data model type and data_model name used
data_model_types = df_experiments.iloc[experiment_loc]["data_model_types"]
# convert it to the enum
data_model_types = [DataModelType[data_model_type] for data_model_type in json.loads(data_model_types)]
data_model_names = [name for name in json.loads(df_experiments.iloc[experiment_loc]["data_model_names"])]
data_model_descriptions = df_experiments.iloc[experiment_loc]["data_model_descriptions"]
for data_model_type in data_model_types:
    print(data_model_type.name)
print(data_model_names)
print(data_model_descriptions)

# print the experiment name
experiment_name = df_experiments.iloc[experiment_loc]["experiment_name"]
print(experiment_name)

# print the experiment problem types
experiment_problem_types = df_experiments.iloc[experiment_loc]["problem_types"]
experiment_problem_types = json.loads(experiment_problem_types)
print(experiment_problem_types)
# Out:
# ed1bfdad-23b3-4929-9601-7126e6fea410
# SweepAtOptimalLambda
# KFeaturesModel
# ['KFeaturesModel_TwoFeatures_ProtectingSecondStronger_AttackingIdentity_[0.5 0.5]_[1 1]_[1 1]_SD_1_1_SU_1_1___SweepAtOptimalLambda']
# ["2 Features, Theta Identity, Sigma_upsilon Identity, Sigma_delta Identity"]
# SweepAtOptimalLambda
# ['Logistic']

# %%
data_model_name_dict = {}
data_model_name_dict["VanillaGaussian"] = "Vanilla Gaussian"
data_model_name_dict["2_VanillaGaussian"] = "Vanilla Gaussian"
data_model_name_dict["VanillaGaussianThetaFirst"] = "Vanilla Gaussian - Teacher 10:1"
data_model_name_dict["VanillaGaussianTimes10"] = "Vanilla Gaussian x10"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[1 1]"] = "Strong Weak 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[1 1]"] = "Strong Weak 5:1"
data_model_name_dict["2_KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[1 1]"] = "Strong Weak 5:1"
data_model_name_dict["2_KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[1 1]"] = "Strong Weak 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[10  1]"] = "Strong Weak 5:1 - Teacher 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[10  1]"] = "Strong Weak 10:1 - Teacher 10:1"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[5 1]_[ 1 10]"] = "Strong Weak 5:1 - Teacher 1:10"
data_model_name_dict["KFeaturesModel_TwoFeatures_ProtectingIdentity_AttackingIdentity_[0.5 0.5]_[10  1]_[ 1 10]"] = "Strong Weak 10:1 - Teacher 1:10"

# %%
state_evolution = df_state_evolution[df_state_evolution["experiment_id" ] == experiment_id]
gd = df_erm[df_erm["experiment_id" ] == experiment_id]
# make the column subspace_overlaps to string
state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: str(x))
gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: str(x))

# create a json colum
state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: json.loads(x))
gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: json.loads(x))
from pandas import json_normalize
# normalize the json column
normalized = json_normalize(state_evolution["subspace_overlaps"])
normalized_gd = json_normalize(gd["subspace_overlaps"])



def explode_array_column(row, col):
    return pd.Series(row[col])

# reset the index of the original dataframe
state_evolution = state_evolution.reset_index(drop=True)
gd = gd.reset_index(drop=True)

for col in normalized.columns:
    expanded_cols = normalized.apply(lambda x: explode_array_column(x,col), axis=1)
    col = col[:-1]
    expanded_cols.columns = [col+'_{}'.format(i) for i in range(expanded_cols.shape[1])]
    # reset the index of the expanded columns
    expanded_cols = expanded_cols.reset_index(drop=True)
    state_evolution = pd.concat([state_evolution, expanded_cols], axis=1)

for col in normalized_gd.columns:
    expanded_cols = normalized_gd.apply(lambda x: explode_array_column(x,col), axis=1)
    col = col[:-1]
    expanded_cols.columns = [col+'_{}'.format(i) for i in range(expanded_cols.shape[1])]
    # reset the index of the expanded columns
    expanded_cols = expanded_cols.reset_index(drop=True)

    gd = pd.concat([gd, expanded_cols], axis=1)
# Out:
# /var/folders/vl/6t_sjl4j16nd3xx4b0t7wd280000gn/T/ipykernel_21746/3541688095.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: str(x))
# /var/folders/vl/6t_sjl4j16nd3xx4b0t7wd280000gn/T/ipykernel_21746/3541688095.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: str(x))
# /var/folders/vl/6t_sjl4j16nd3xx4b0t7wd280000gn/T/ipykernel_21746/3541688095.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_evolution["subspace_overlaps"] = state_evolution["subspace_overlaps"].apply(lambda x: json.loads(x))
# /var/folders/vl/6t_sjl4j16nd3xx4b0t7wd280000gn/T/ipykernel_21746/3541688095.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gd["subspace_overlaps"] = gd["subspace_overlaps"].apply(lambda x: json.loads(x))

# %%
state_evolution["subspace_overlaps_ratio"] = state_evolution["subspace_overlaps_ratio"].apply(lambda x: str(x))
state_evolution["subspace_overlaps_ratio"] = state_evolution["subspace_overlaps_ratio"].apply(lambda x: json.loads(x))
normalized = json_normalize(state_evolution["subspace_overlaps_ratio"])
# rename the columns of the normalized dataframe
for column in normalized.columns:
    normalized = normalized.rename(columns={column:column+"_ratio"})
# merge the normalized dataframe with the original dataframe
state_evolution = pd.concat([state_evolution, normalized], axis=1)
# drop the original subspace_overlaps column
state_evolution = state_evolution.drop(columns=["subspace_overlaps_ratio"])

gd["subspace_overlaps_ratio"] = gd["subspace_overlaps_ratio"].apply(lambda x: str(x))
gd["subspace_overlaps_ratio"] = gd["subspace_overlaps_ratio"].apply(lambda x: json.loads(x))
normalized = json_normalize(gd["subspace_overlaps_ratio"])
# rename the columns of the normalized dataframe
for column in normalized.columns:
    normalized = normalized.rename(columns={column:column+"_ratio"})
# merge the normalized dataframe with the original dataframe
gd = pd.concat([gd, normalized], axis=1)
# drop the original subspace_overlaps column
gd = gd.drop(columns=["subspace_overlaps_ratio"])

# %%
# create a column for the difference between the adversarial_generalization_error and the generalization_error for both the state evolution and the erm
state_evolution["difference_adv_gen"] = state_evolution["adversarial_generalization_error"] - state_evolution["generalization_error"]
gd["difference_adv_gen"] = gd["adversarial_generalization_error"] - gd["generalization_error_erm"]


state_evolution["ratio_adv_gen"] = state_evolution["adversarial_generalization_error"] / state_evolution["generalization_error"]
gd["ratio_adv_gen"] = gd["adversarial_generalization_error"] / gd["generalization_error_erm"]

# %%
# create a column for the noise contribution
def noise_contribution(rho: float, tau: float) -> float:
    if tau == 0:
        tau = 1e-10
    return 0.5 - np.arctan( np.sqrt( rho / tau**2 ) ) / np.pi

state_evolution["noise_contribution"] = state_evolution.apply(lambda x: noise_contribution(x["rho"], x["tau"]), axis=1)
gd["noise_contribution"] = gd.apply(lambda x: noise_contribution(x["rho"], x["tau"]), axis=1)

# %%
# create a column for the noiseless generalization error without the noise contribution
state_evolution["noiseless_generalization_error"] = state_evolution["generalization_error"] - state_evolution["noise_contribution"]
gd["noiseless_generalization_error_erm"] = gd["generalization_error_erm"] - gd["noise_contribution"]

# create a column for the adversarial noiseless generalization error without the noise contribution
state_evolution["noiseless_adversarial_generalization_error"] = state_evolution["adversarial_generalization_error"] - state_evolution["noise_contribution"]
gd["noiseless_adversarial_generalization_error"] = gd["adversarial_generalization_error"] - gd["noise_contribution"]

# %%
# create a column for the A/sqrt(q*N) for both the state evolution and the erm
state_evolution["A_over_sqrt_qN"] = state_evolution["A"] / np.sqrt(state_evolution["q"] * state_evolution["N"])
gd["A_over_sqrt_qN"] = gd["A"] / np.sqrt(gd["q"] * gd["N"])

# %%
# create a column for m/sqrt( rho*q - m**2 ) vs A/sqrt(q*N) for both the state evolution and the erm
state_evolution["m_over_sqrt_rhoq_minus_m2"] = state_evolution["m"] / np.sqrt(state_evolution["rho"] * state_evolution["q"] - state_evolution["m"]**2)
gd["m_over_sqrt_rhoq_minus_m2"] = gd["m"] / np.sqrt(gd["rho"] * gd["q"] - gd["m"]**2)

# %%
# strip the data_model_name if there is a sequence ___text at the end
def strip_data_model_name(data_model_name):
    return re.sub(r"___.*","",data_model_name)
state_evolution["data_model_name"] = state_evolution["data_model_name"].apply(strip_data_model_name)
gd["data_model_name"] = gd["data_model_name"].apply(strip_data_model_name)

# %%
gd = gd.set_index(["alpha","epsilon","tau","lam","problem_type","attack_epsilon","data_model_name"]) #,"p_calibration"
state_evolution = state_evolution.set_index(["alpha","epsilon","tau","lam","problem_type","attack_epsilon","data_model_name"]) #,"p_calibration"

# drop id, code_version, experiment_id, date, initial_condition, test_against_epsilons, calibrations, abs_tol, min_iter,max_iter,blend_fpe,int_lims,subspace_overlaps
state_evolution = state_evolution.drop(columns=["id","code_version","experiment_id","date","initial_condition","test_against_epsilons","calibrations","abs_tol","min_iter","max_iter","blend_fpe","int_lims","subspace_overlaps","data_model_type","data_model_description"])
# drop id, code_version, experiment_id, test_against_epsilons, date, subspace_overlaps, analytical_calibrations, erm_calibrations, 
gd = gd.drop(columns=["id","code_version","experiment_id","test_against_epsilons","date","subspace_overlaps","analytical_calibrations","erm_calibrations","data_model_type","data_model_description"])

state_evolution.columns = [col+"_state_evolution" for col in state_evolution.columns]
gd.columns = [col+"_erm" for col in gd.columns]

state_evolution = state_evolution.groupby(level=[0,1,2,3,4,5,6]).agg(["mean","std"]) #,4
gd = gd.groupby(level=[0,1,2,3,4,5,6]).agg(["mean","std"]) #,4
df = state_evolution.join(gd, how="outer")
df.sort_index()
df
# Out:
#                                                                                                                  index_state_evolution  \
#                                                                                                                                   mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61380.0
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61381.0
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61382.0
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61383.0
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61384.0
# ...                                                                                                                                ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61455.0
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61456.0
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61457.0
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61458.0
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               61459.0
#
#                                                                                                                       \
#                                                                                                                  std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# ...                                                                                                               ..
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#
#                                                                                                                  duration_state_evolution  \
#                                                                                                                                      mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.075995
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.170928
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.506657
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.402987
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.091644
# ...                                                                                                                                   ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.839577
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.165757
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.419628
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 1.307249
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                 0.824222
#
#                                                                                                                       \
#                                                                                                                  std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# ...                                                                                                               ..
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#
#                                                                                                                  generalization_error_state_evolution  \
#                                                                                                                                                  mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.104701
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.104758
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.104988
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.106270
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.103578
# ...                                                                                                                                               ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.092383
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.086857
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.086933
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.087423
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                             0.091789
#
#                                                                                                                       \
#                                                                                                                  std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# ...                                                                                                               ..
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#
#                                                                                                                  training_loss_state_evolution  \
#                                                                                                                                           mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.044067
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      1.539270
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      9.066393
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                     20.342743
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.043686
# ...                                                                                                                                        ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                     10.266009
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      0.038111
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.080028
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                     19.485463
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                     10.021552
#
#                                                                                                                       \
#                                                                                                                  std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# ...                                                                                                               ..
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#
#                                                                                                                  training_error_state_evolution  \
#                                                                                                                                            mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.000041
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.000209
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.001025
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.004960
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.000043
# ...                                                                                                                                         ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.009954
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.000069
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.000373
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.002076
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                       0.010192
#
#                                                                                                                       \
#                                                                                                                  std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# ...                                                                                                               ..
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro... NaN
#
#                                                                                                                   ...  \
#                                                                                                                   ...
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name                                     ...
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
# ...                                                                                                               ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  ...
#
#                                                                                                                  noise_contribution_erm  \
#                                                                                                                                    mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.016021
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.016133
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.016121
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.015911
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.015827
# ...                                                                                                                                 ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.015774
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.016136
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.016085
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.015692
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...               0.016152
#
#                                                                                                                             \
#                                                                                                                        std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000706
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000605
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000260
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000454
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000367
# ...                                                                                                                    ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000538
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000446
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000523
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000381
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.000616
#
#                                                                                                                  noiseless_generalization_error_erm_erm  \
#                                                                                                                                                    mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.088839
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.088207
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.085129
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.091639
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.087293
# ...                                                                                                                                                 ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.076146
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.071004
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.072915
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.071518
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                               0.077378
#
#                                                                                                                             \
#                                                                                                                        std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.007639
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.006161
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.005659
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.006059
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.004858
# ...                                                                                                                    ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.003884
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.004002
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.005544
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.004557
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.002714
#
#                                                                                                                  noiseless_adversarial_generalization_error_erm  \
#                                                                                                                                                            mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.132839
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.132657
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.128799
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.137249
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.131833
# ...                                                                                                                                                         ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.122016
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.116284
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.117845
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.115908
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                                       0.122628
#
#                                                                                                                             \
#                                                                                                                        std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.008828
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.005001
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.004870
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.006021
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.005238
# ...                                                                                                                    ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.003875
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.004567
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.004775
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.004051
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.003779
#
#                                                                                                                  A_over_sqrt_qN_erm  \
#                                                                                                                                mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
# ...                                                                                                                             ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                1.0
#
#                                                                                                                        \
#                                                                                                                   std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
# ...                                                                                                               ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.0
#
#                                                                                                                  m_over_sqrt_rhoq_minus_m2_erm  \
#                                                                                                                                           mean
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      2.991125
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      2.984071
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.049778
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      2.955534
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      2.988787
# ...                                                                                                                                        ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.422636
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.630712
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.596654
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.602435
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...                      3.385563
#
#
#                                                                                                                        std
# alpha  epsilon tau  lam           problem_type attack_epsilon data_model_name
# 4.0000 0.0     0.05  6.834190e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.159245
#        0.1     0.05  6.425580e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.134965
#        0.2     0.05  3.786880e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.169048
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.163536
# 4.0526 0.0     0.05  6.706640e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.132724
# ...                                                                                                                    ...
# 4.9474 0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.080523
# 5.0000 0.0     0.05  4.959560e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.144901
#        0.1     0.05  4.290300e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.189217
#        0.2     0.05  1.335140e-03 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.159100
#        0.3     0.05 -9.900000e-07 Logistic     0.1            KFeaturesModel_TwoFeatures_ProtectingSecondStro...  0.049026
#
# [80 rows x 248 columns]

# %%
# store the dataframe as a pickle file
if not os.path.exists("Pickles"):
    os.makedirs("Pickles")
if not os.path.exists("Pickles/gen_optimal_lam.pkl"):
    df.to_pickle("Pickles/gen_optimal_lam.pkl")

# %% [markdown]
# # extracting the data

# %%
# get unique epsilons
epsilons = df.index.get_level_values(1).unique()
epsilons
# Out:
# Index([0.0, 0.1, 0.2, 0.3], dtype='float64', name='epsilon')

# %%
# get unique attack_epsilons
attack_epsilons = df.index.get_level_values(5).unique()
attack_epsilons
# Out:
# Index([0.1], dtype='float64', name='attack_epsilon')

# %%
# create a dictionary of dataframes for each data_model_name
epsilon_dict = {}
for epsilon in epsilons:

    eps_df = df.xs(epsilon, level="epsilon")

    

    

    lams = eps_df.index.get_level_values("lam").unique()
    adversarial_error_0 = eps_df["adversarial_generalization_error_state_evolution"]["mean"].values
    generalization_error_0 = eps_df["generalization_error_state_evolution"]["mean"].values
    boundary_error_0 = eps_df["difference_adv_gen_state_evolution"]["mean"].values

    lams = np.array(lams)
    adversarial_error_0 = np.array(adversarial_error_0)
    generalization_error_0 = np.array(generalization_error_0)
    boundary_error_0 = np.array(boundary_error_0)

    eps_0_dict = {}
    eps_0_dict["lams"] = lams
    eps_0_dict["adversarial_error"] = adversarial_error_0
    eps_0_dict["generalization_error"] = generalization_error_0
    eps_0_dict["boundary_error"] = boundary_error_0


    epsilon_dict[epsilon] = eps_0_dict

# %%
np.argmin(epsilon_dict[0.02]["generalization_error"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 np.argmin(epsilon_dict[0.02]["generalization_error"])
#
# KeyError: 0.02

# %% [markdown]
# # Figure saving

# %%
IMG_DIRECTORY = "./Assets/gen_optimal_lambda"
if not os.path.exists(IMG_DIRECTORY):
    os.makedirs(IMG_DIRECTORY)


def save_plot(fig, name, formats=["pdf","jpg"], date=False):
    current_date = datetime.datetime.now().strftime("%Y-%m-%d")
    for f in formats:        
        path = "{}".format(name) + "_{}".format(current_date) + "." + f
        if not date:
            path = "{}".format(name) + "." + f
        fig.savefig(            
            os.path.join(IMG_DIRECTORY, path),
            format=f,
        )


def set_size(width, fraction=1, subplots=(1, 1)):
    if width == "thesis":
        width_pt = 426.79135
    elif width == "beamer":
        width_pt = 307.28987
    else:
        width_pt = width

    fig_width_pt = width_pt * fraction
    inches_per_pt = 1 / 72.27

    golden_ratio = (5**0.5 - 1) / 2

    fig_width_in = fig_width_pt * inches_per_pt
    fig_height_in = fig_width_in * (golden_ratio) * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)


width = 1.25 * 458.63788

plt.style.use("../latex_ready.mplstyle")

tuple_size = set_size(width, fraction=0.50)

multiplier = 1.0
second_multiplier = 0.7

fig, axs = plt.subplots(
    nrows=1,
    ncols=1,
    sharex=True,
    figsize=(multiplier * tuple_size[0], 0.75 * multiplier * tuple_size[0]),
    gridspec_kw={"hspace": 0},
)


# ICML adjustments
# fig.subplots_adjust(left=0.16)
# fig.subplots_adjust(bottom=0.16)
# fig.subplots_adjust(top=0.97)
# fig.subplots_adjust(right=0.97)

linestyles = ["solid", "dashed", "dashdot", "dotted"]

for idx, (epsilon, eps_dict) in enumerate(epsilon_dict.items()):
    if epsilon >0.2:
        continue

    lams = eps_dict["lams"]
    adversarial_error = eps_dict["adversarial_error"]
    generalization_error = eps_dict["generalization_error"]
    boundary_error = eps_dict["boundary_error"]


    # axs.plot(lams, adversarial_error, label=r"$E_{\mathrm{adv}}$", color="C0", linestyle=linestyles[idx])
    axs.plot(lams, generalization_error, label=r"$E_{{\mathrm{{gen}}}}, \varepsilon_t={}$".format(epsilon), color="C1", linestyle=linestyles[idx])
    # axs.plot(lams, boundary_error, label=r"$E_{\mathrm{bound}}$", color="C2", linestyle=linestyles[idx])



# axs.set_xscale("log")
axs.set_yscale("log")
axs.set_ylabel(r"$E$", labelpad=2.0)
axs.set_xlabel(r"$\lambda$", labelpad=2.0)
axs.grid(which="both", axis="both", alpha=0.5)
axs.legend()

plt.tight_layout()

save = True
if save:
    save_plot(
        fig,
        "gen_lambda_optimal_sweep",
    )

plt.show()

# %%
# let's extract the adversarial generalisation error, the boundary error and the generalisation error into a numpy array
